# %% [markdown]
# ## Imports

# %%
from sklearn.preprocessing import OneHotEncoder, FunctionTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import regex as re
import pandas as pd
import numpy as np
import random 
import pycountry
np.random.seed = 42
random.seed(42)

pd.set_option('display.max_columns', None)
pd.set_option('display.min_rows', 10)

# %% [markdown]
# ## Data Format

# %%
mailchimp_data = pd.read_csv('./data/MailChimp cleaned records headers.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.min_rows', 10)
mailchimp_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS]
# Index: []

# %% [markdown]
# The mailchimp dataset comes from the salesforce dataset. This Cleaned dataset would only include emails that have bounced for one reason or another. It will not include any members who have opted out of the email service or those that are receiving emails without any complications. It is important to note that updating information within salesforce for those who have opted out may re-instantiate the email services so we are specifically working with cleaned/bounced records. Additionally, the datasets created for those who are Subscribed and Unsubscribed will have different column names than the Cleaned dataset here (ie Clean_Time, Clean_campaign_title, ect). Therefore any function created here may not work for those datasets.

# %%
saa_pride_data = pd.read_excel('./data/SAA Pride member reports headings.xlsx')
saa_pride_data.reset_index(inplace = True)
saa_pride_data
# Out:
# Empty DataFrame
# Columns: [index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %% [markdown]
# The Stanford Alumni Association has it's own dataset that may or may not have additional or more recent data on some of the members. It may also have outdated data. Students are given an email but when they become alumni the email needs to be updated. Whether it is updated to specifically an 'alumni.stanford.edu' address or to another would be at the students discrepancy and isn't always updated.

# %% [markdown]
# ## Helper Functions

# %%
def mapCountry(countryStr):
    if countryStr not in [np.nan, None, 'nan','*', '','N/A','n/a']:
        return pycountry.countries.search_fuzzy(countryStr)[0].alpha_3
    return 'n/a'

# %%
def ohe(df, column):    
    for col in column:
        train = df[[col]]
        ohe = OneHotEncoder(sparse=False, handle_unknown="error")
        ohe.fit(train)
        encoded_train = ohe.transform(train)
        col_names = [f"{col}_{f}" for f in ohe.get_feature_names()]
        encoded_train = pd.DataFrame(encoded_train,
                                     columns=col_names, index=df.index)
        df = pd.concat([df, encoded_train], axis=1)
        
    return df

# %%
def parseDegreeCol(df,deg_colName='short_degree_string'):
    vectorizer = CountVectorizer()
    
    t = vectorizer.fit_transform(df[deg_colName])
    
    # Remove original degree column from original dataframe
    df = df.drop(columns=[deg_colName])
    
    # Create new vectorized degree columns and concatenate
    deg_df =  pd.DataFrame(t.toarray(),columns=vectorizer.get_feature_names(),index = df.index)
    if 'nan' in deg_df.columns:
        deg_df.drop(columns = 'nan')
    return pd.concat([df,deg_df],axis = 1).fillna(0)

# %% [markdown]
# ### Pokemon Data

# %%
df_saa_original = pd.read_excel('./data/SAA_Pokemon_FakeDB.xlsx')
df_saa_original
# Out:
#       pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 0                NaN           2004.0  Shanghai             NaN            *
# 1                NaN              NaN    Madrid             NaN        China
# 2                NaN              NaN     Seoul             NaN       Kuwait
# 3                NaN              NaN    London             NaN          NaN
# 4                NaN              NaN    London             NaN          USA
# ...              ...              ...       ...             ...          ...
# 3995             NaN              NaN    Boston              MA        Japan
# 3996             NaN           2000.0  Shanghai             NaN          NaN
# 3997             NaN              NaN       NaN             NaN       Kuwait
# 3998             NaN              NaN       NaN             NaN        Japan
# 3999             NaN              NaN    Boston              MA          USA
#
#       home_phone_area_code home_phone_number  \
# 0                      NaN                 *
# 1                      NaN               NaN
# 2                      NaN               NaN
# 3                      NaN                 *
# 4                      NaN      775 0678-214
# ...                    ...               ...
# 3995                   NaN               NaN
# 3996                   NaN                 *
# 3997                   NaN               NaN
# 3998                   NaN               NaN
# 3999                   NaN               NaN
#
#                                home_email_address  bus_city  bus_state_code  \
# 0                                             NaN       NaN             NaN
# 1                  weedleg4046@stanfordalumni.org       NaN             NaN
# 2     aerodactyl.electric2974@alumni.stanford.edu       NaN             NaN
# 3                                               *       NaN             NaN
# 4                                               *       NaN             NaN
# ...                                           ...       ...             ...
# 3995                                            *       NaN             NaN
# 3996        kabutops.steel1285@stanfordalumni.org       NaN             NaN
# 3997                                            *       NaN             NaN
# 3998     larvitar.electric9778@stanfordalumni.org       NaN             NaN
# 3999                                            *       NaN             NaN
#
#         bus_country  bus_phone_area_code  bus_phone_number  \
# 0               NaN                  NaN               NaN
# 1             China                  NaN               NaN
# 2            Kuwait                  NaN               NaN
# 3             Japan                  NaN               NaN
# 4               NaN                  NaN               NaN
# ...             ...                  ...               ...
# 3995            NaN                  NaN               NaN
# 3996          China                  NaN               NaN
# 3997            NaN                  NaN               NaN
# 3998  United States                  NaN               NaN
# 3999         Kuwait                  NaN               NaN
#
#          bus_email_address  first_name last_name  pref_name_sort  \
# 0                      NaN   Growlithe       Ice             NaN
# 1                      NaN      Weedle     Grass             NaN
# 2                      NaN  Aerodactyl  Electric             NaN
# 3                      NaN      Pinsir      Fire             NaN
# 4                      NaN      Horsea       Ice             NaN
# ...                    ...         ...       ...             ...
# 3995                   NaN    Smeargle  Electric             NaN
# 3996                   NaN    Kabutops     Steel             NaN
# 3997                   NaN    Slowking    Dragon             NaN
# 3998                   NaN    Larvitar  Electric             NaN
# 3999  u.dark7601@gmail.com    Ursaring      Dark             NaN
#
#                            email_switch                     saa_email_address  \
# 0                                   NaN                                     *
# 1                                   NaN       w.grass5053@alumni.stanford.edu
# 2                                   NaN                                     *
# 3              pinsirfire4582@gmail.com                                     *
# 4           hice7313@stanfordalumni.org                                   NaN
# ...                                 ...                                   ...
# 3995     smeargleelectric9444@gmail.com                                     *
# 3996    k.steel5317@alumni.stanford.edu                                   NaN
# 3997                                NaN      slowkingd5563@stanfordalumni.org
# 3998  l.electric7920@stanfordalumni.org                                   NaN
# 3999      u.dark1814@stanfordalumni.org  ursaring.dark7398@stanfordalumni.org
#
#      gsb_email_address  other_email_address  pref_phone_area_code  \
# 0                  NaN                  NaN                   NaN
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                  NaN                  NaN                   NaN
# ...                ...                  ...                   ...
# 3995               NaN                  NaN                   NaN
# 3996               NaN                  NaN                   NaN
# 3997               NaN                  NaN                   NaN
# 3998               NaN                  NaN                   NaN
# 3999               NaN                  NaN                   NaN
#
#       pref_phone_number  pref_phone_addr_type  memb_status_desc  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
# ...                 ...                   ...               ...
# 3995                NaN                   NaN               NaN
# 3996                NaN                   NaN               NaN
# 3997                NaN                   NaN               NaN
# 3998                NaN                   NaN               NaN
# 3999                NaN                   NaN               NaN
#
#        short_degree_string  parent_degree_string  short_degree_string_spouse  \
# 0                      NaN                   NaN                         NaN
# 1                      '82                   NaN                         NaN
# 2                      NaN                   NaN                         NaN
# 3          JD '94, PhD '97                   NaN                         NaN
# 4                      NaN                   NaN                         NaN
# ...                    ...                   ...                         ...
# 3995      PhD '96, MBA '87                   NaN                         NaN
# 3996                BS '93                   NaN                         NaN
# 3997       PhD '84, JD '93                   NaN                         NaN
# 3998  MBA '92, '98, JD '86                   NaN                         NaN
# 3999       BS '94, PhD '97                   NaN                         NaN
#
#       parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind
# 0                             NaN                NaN        NaN          NaN
# 1                             NaN                NaN        NaN          NaN
# 2                             NaN                NaN        NaN          NaN
# 3                             NaN                NaN        NaN          NaN
# 4                             NaN                NaN        NaN          NaN
# ...                           ...                ...        ...          ...
# 3995                          NaN                NaN        NaN          NaN
# 3996                          NaN                NaN        NaN          NaN
# 3997                          NaN                NaN        NaN          NaN
# 3998                          NaN                NaN        NaN          NaN
# 3999                          NaN                NaN        NaN          NaN
#
# [4000 rows x 32 columns]

# %% [markdown]
# # Preprocess SAA dataframe

# %% [markdown]
# Preprocessing steps:
# 1. Filter out columns
# 2. Impute nans
# 3. Strip and lower case
# 4. Retain handles in emails, remove domain.
# 5. Clean Degree string

# %% [markdown]
# ## Preprocessing functions
#
# We will be using pipelines and column transformers to streamline our preprocessing workflow on the SAA database. We will be defining preprocessing functions that will be used in our pipeline and Column Transformers.

# %%
# Filter necessary columns
def filter_columns(df,columns):
    return df.filter(columns)
filter_cols = FunctionTransformer(filter_columns,kw_args={'columns':main_cols})

#Strip and lower case
def strip_lower(arr):    
    arr = np.char.lower(np.char.strip(arr.astype(str)))
    return arr
standardize_str = FunctionTransformer(strip_lower)

#Remove email domains
def remove_domains(df,columns):
#     email_cols = ['home_email_address', 'bus_email_address', 'email_switch',
#                   'saa_email_address', 'gsb_email_address', 'other_email_address']
    df = df.filter(columns)
    for email in columns:
        df[email] = df[email].apply(removeEmailDomain)
    return df
email_domain = FunctionTransformer(remove_domains,kw_args={'columns':email_cols})

#Clean degree string
def cleanDegreeStr(degree):
    no_nums_puncs = re.sub('[;,\'*0-9]', ' ', degree).strip()
    return re.sub('[ ]+', ' ', no_nums_puncs).strip()

def clean_degrees(arr):
    cleanDegreeStr_vec = np.vectorize(cleanDegreeStr)
    arr = cleanDegreeStr_vec(arr)
    return arr
cleaned_degrees = FunctionTransformer(clean_degrees)

# %% [markdown]
# ## Subpipes and Column Transformers

# %%
# We'll throw these mini-pipelines into our ColumnTransformer

main_cols = ['first_name', 'last_name', 'home_country', 'bus_country']
email_cols = ['home_email_address', 'bus_email_address', 'email_switch',\
              'saa_email_address', 'gsb_email_address', 'other_email_address']

#subpipe that handles our the majority of our columns
subpipe_main= Pipeline(steps=[('get_cols', filter_cols),
                         ('simple_impute', SimpleImputer(strategy='constant', fill_value='n/a')),
                         ('string_out', standardize_str),
#                          ('emails',email_domain)
                         ])

#subpipe that handles our our emails
subpipe_email = Pipeline(steps=[('emails',email_domain),
                         ('simple_impute', SimpleImputer(strategy='constant', fill_value='n/a')),
                         ('string_out', standardize_str)
                         ])

#subpipe that handles degrees owned columns
subpipe_degree = Pipeline(steps=[('simple_impute', SimpleImputer(strategy='constant', fill_value='n/a')),
                                 ('degree',cleaned_degrees),
                                 ('string_out', standardize_str)
                         ])

# %%
#Combine subpipes into CT
ct = ColumnTransformer(transformers = [
    ('subpipe_main', subpipe_main, df_saa_original.columns),
    ('subpipe_emails', subpipe_email, df_saa_original.columns),
    ('subpipe_degrees', subpipe_degree, [25] )
])

# %%
#Test out our first column transformer
columns = ['first_name', 'last_name','home_country', 'bus_country',\
           'home_email_address', 'bus_email_address', 'email_switch',\
                  'saa_email_address', 'gsb_email_address', 'other_email_address',\
          'short_degree_string']
ct_test_df = pd.DataFrame(ct.fit_transform(df_saa_original),columns=columns)
ct_test_df
# Out:
#       first_name last_name home_country    bus_country  \
# 0      growlithe       ice            *            n/a
# 1         weedle     grass        china          china
# 2     aerodactyl  electric       kuwait         kuwait
# 3         pinsir      fire          n/a          japan
# 4         horsea       ice          usa            n/a
# ...          ...       ...          ...            ...
# 3995    smeargle  electric        japan            n/a
# 3996    kabutops     steel          n/a          china
# 3997    slowking    dragon       kuwait            n/a
# 3998    larvitar  electric        japan  united states
# 3999    ursaring      dark          usa         kuwait
#
#            home_email_address bus_email_address          email_switch  \
# 0                         n/a               n/a                   n/a
# 1                 weedleg4046               n/a                   n/a
# 2     aerodactyl.electric2974               n/a                   n/a
# 3                         n/a               n/a        pinsirfire4582
# 4                         n/a               n/a              hice7313
# ...                       ...               ...                   ...
# 3995                      n/a               n/a  smeargleelectric9444
# 3996       kabutops.steel1285               n/a           k.steel5317
# 3997                      n/a               n/a                   n/a
# 3998    larvitar.electric9778               n/a        l.electric7920
# 3999                      n/a        u.dark7601            u.dark1814
#
#       saa_email_address gsb_email_address other_email_address  \
# 0                   n/a               n/a                 n/a
# 1           w.grass5053               n/a                 n/a
# 2                   n/a               n/a                 n/a
# 3                   n/a               n/a                 n/a
# 4                   n/a               n/a                 n/a
# ...                 ...               ...                 ...
# 3995                n/a               n/a                 n/a
# 3996                n/a               n/a                 n/a
# 3997      slowkingd5563               n/a                 n/a
# 3998                n/a               n/a                 n/a
# 3999  ursaring.dark7398               n/a                 n/a
#
#      short_degree_string
# 0                    n/a
# 1
# 2                    n/a
# 3                 jd phd
# 4                    n/a
# ...                  ...
# 3995             phd mba
# 3996                  bs
# 3997              phd jd
# 3998              mba jd
# 3999              bs phd
#
# [4000 rows x 11 columns]

# %% [markdown]
# # Mail Chimp Dataframe

# %%
df_mailchimp_original = pd.read_csv('./data/Fake_MailChimp_cleaned_Pokemon.csv')
df_mailchimp_original
# Out:
#                          Email Address First Name Last Name  Board Member  \
# 0         slakoth.normal3945@gmail.com    Slakoth    Normal         False
# 1                 e.rock7454@gmail.com     Espeon      Rock          True
# 2  rhydonghost7966@alumni.stanford.edu     Rhydon     Ghost         False
# 3      porygong9247@stanfordalumni.org    Porygon     Grass         False
# 4           tangelagrass1376@gmail.com    Tangela     Grass         False
# 5             c.electric7518@gmail.com    Chansey     Steel          True
# 6          blissey.ghost4154@gmail.com    Blissey     Ghost         False
#
#   Gender      Chapter  Reunion Year  \
# 0    NaN        Texas           NaN
# 1      F      DC Area           NaN
# 2      M     Bay Area           NaN
# 3      M     Bay Area           NaN
# 4    NaN  New England           NaN
# 5      F     Other US           NaN
# 6      M  New England           NaN
#
#                                         Country Degree  MEMBER_RATING  \
# 0                                           USA    NaN            NaN
# 1                                 United States    NaN            NaN
# 2                                           USA    MBA            NaN
# 3                                         Japan     MS            NaN
# 4                                 United States    NaN            NaN
# 5                                           USA    NaN            NaN
# 6  Macao Special Administrative Region of China    NaN            NaN
#
#    OPTIN_TIME  OPTIN_IP  CONFIRM_TIME  CONFIRM_IP  LATITUDE  LONGITUDE  \
# 0         NaN       NaN           NaN         NaN       NaN        NaN
# 1         NaN       NaN           NaN         NaN       NaN        NaN
# 2         NaN       NaN           NaN         NaN       NaN        NaN
# 3         NaN       NaN           NaN         NaN       NaN        NaN
# 4         NaN       NaN           NaN         NaN       NaN        NaN
# 5         NaN       NaN           NaN         NaN       NaN        NaN
# 6         NaN       NaN           NaN         NaN       NaN        NaN
#
#    GMTOFF  DSTOFF  TIMEZONE  CC  REGION  CLEAN_TIME  CLEAN_CAMPAIGN_TITLE  \
# 0     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 1     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 2     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 3     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 4     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 5     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 6     NaN     NaN       NaN NaN     NaN         NaN                   NaN
#
#    CLEAN_CAMPAIGN_ID  LEID  EUID  NOTES  TAGS
# 0                NaN   NaN   NaN    NaN   NaN
# 1                NaN   NaN   NaN    NaN   NaN
# 2                NaN   NaN   NaN    NaN   NaN
# 3                NaN   NaN   NaN    NaN   NaN
# 4                NaN   NaN   NaN    NaN   NaN
# 5                NaN   NaN   NaN    NaN   NaN
# 6                NaN   NaN   NaN    NaN   NaN

# %% [markdown]
# # Preprocess mailchimp dataframe

# %%
# Filter necessary columns
df_mailchimp = df_mailchimp_original.filter(['First Name', 'Last Name', 'Email Address',
                                         'Degree', 'Country'])
df_mailchimp
# Out:
#   First Name Last Name                        Email Address Degree  \
# 0    Slakoth    Normal         slakoth.normal3945@gmail.com    NaN
# 1     Espeon      Rock                 e.rock7454@gmail.com    NaN
# 2     Rhydon     Ghost  rhydonghost7966@alumni.stanford.edu    MBA
# 3    Porygon     Grass      porygong9247@stanfordalumni.org     MS
# 4    Tangela     Grass           tangelagrass1376@gmail.com    NaN
# 5    Chansey     Steel             c.electric7518@gmail.com    NaN
# 6    Blissey     Ghost          blissey.ghost4154@gmail.com    NaN
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# ## Apply Preprocessing subpipes and CT to mailchimp dataframe
#
# We need to change the columns specified for some of the functions in the subpipe. There might be a less redundant way to do this but for now, we'll proceed.

# %%
# We'll throw these mini-pipelines into our ColumnTransformer

main_cols = ['First Name', 'Last Name']
email_cols = ['Email Address']

#subpipe that handles our the majority of our columns
subpipe_main= Pipeline(steps=[('get_cols', FunctionTransformer(filter_columns,kw_args={'columns':main_cols})),
                         ('simple_impute', SimpleImputer(strategy='constant', fill_value='n/a')),
                         ('string_out', standardize_str),
#                          ('emails',email_domain)
                         ])

#subpipe that handles our our emails
subpipe_email = Pipeline(steps=[('emails',FunctionTransformer(remove_domains,kw_args={'columns':email_cols})),
                         ('simple_impute', SimpleImputer(strategy='constant', fill_value='n/a')),
                         ('string_out', standardize_str)
                         ])

# %%
ct_mailchimp = ColumnTransformer(transformers = [
    ('subpipe_main', subpipe_main, df_mailchimp.columns),
    ('subpipe_emails', subpipe_email, df_mailchimp.columns),
    ('subpipe_degrees', subpipe_degree, [3] )
])

# %%
#Test out our first column transformer
columns = ['First Name', 'Last Name', 'Email Address','Degree']
ct_test_df = pd.DataFrame(ct.fit_transform(df_mailchimp),columns=columns)
ct_test_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pref_mail_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\__init__.py in _get_column_indices(X, key)
#     446             for col in columns:
# --> 447                 col_idx = all_columns.get_loc(col)
#     448                 if not isinstance(col_idx, numbers.Integral):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#
# KeyError: 'pref_mail_name'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-ee4cd1038619> in <module>
#       1 #Test out our first column transformer
#       2 columns = ['First Name', 'Last Name', 'Email Address','Degree']
# ----> 3 ct_test_df = pd.DataFrame(ct.fit_transform(df_mailchimp),columns=columns)
#       4 ct_test_df
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     527         self._validate_transformers()
#     528         self._validate_column_callables(X)
# --> 529         self._validate_remainder(X)
#     530
#     531         result = self._fit_transform(X, y, _fit_transform_one)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\compose\_column_transformer.py in _validate_remainder(self, X)
#     325         cols = []
#     326         for columns in self._columns:
# --> 327             cols.extend(_get_column_indices(X, columns))
#     328
#     329         remaining_idx = sorted(set(range(self._n_features)) - set(cols))
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\__init__.py in _get_column_indices(X, key)
#     452
#     453         except KeyError as e:
# --> 454             raise ValueError(
#     455                 "A given column is not a column of the dataframe"
#     456             ) from e
#
# ValueError: A given column is not a column of the dataframe

# %% [markdown]
# ## Filter necessary columns

# %%
# Filter necessary columns
df_mailchimp = df_mailchimp_original.filter(['First Name', 'Last Name', 'Email Address',
                                         'Degree', 'Country'])
df_mailchimp
# Out:
#   First Name Last Name                        Email Address Degree  \
# 0    Slakoth    Normal         slakoth.normal3945@gmail.com    NaN
# 1     Espeon      Rock                 e.rock7454@gmail.com    NaN
# 2     Rhydon     Ghost  rhydonghost7966@alumni.stanford.edu    MBA
# 3    Porygon     Grass      porygong9247@stanfordalumni.org     MS
# 4    Tangela     Grass           tangelagrass1376@gmail.com    NaN
# 5    Chansey     Steel             c.electric7518@gmail.com    NaN
# 6    Blissey     Ghost          blissey.ghost4154@gmail.com    NaN
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# ## Replace nulls with 'n/a'

# %%
df_mailchimp.fillna('n/a',inplace=True)
df_mailchimp
# Out:
#   First Name Last Name                        Email Address Degree  \
# 0    Slakoth    Normal         slakoth.normal3945@gmail.com    n/a
# 1     Espeon      Rock                 e.rock7454@gmail.com    n/a
# 2     Rhydon     Ghost  rhydonghost7966@alumni.stanford.edu    MBA
# 3    Porygon     Grass      porygong9247@stanfordalumni.org     MS
# 4    Tangela     Grass           tangelagrass1376@gmail.com    n/a
# 5    Chansey     Steel             c.electric7518@gmail.com    n/a
# 6    Blissey     Ghost          blissey.ghost4154@gmail.com    n/a
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# ## Strip and lowercase all names and emails

# %%
for col in ['First Name','Last Name','Email Address','Degree']:
    df_mailchimp[col] = df_mailchimp[col].str.lower().str.strip()
df_mailchimp
# Out:
#   First Name Last Name                        Email Address Degree  \
# 0    slakoth    normal         slakoth.normal3945@gmail.com    n/a
# 1     espeon      rock                 e.rock7454@gmail.com    n/a
# 2     rhydon     ghost  rhydonghost7966@alumni.stanford.edu    mba
# 3    porygon     grass      porygong9247@stanfordalumni.org     ms
# 4    tangela     grass           tangelagrass1376@gmail.com    n/a
# 5    chansey     steel             c.electric7518@gmail.com    n/a
# 6    blissey     ghost          blissey.ghost4154@gmail.com    n/a
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# ## Remove email domain

# %%
df_mailchimp['Email Address'] = df_mailchimp['Email Address'].apply(removeEmailDomain)
df_mailchimp
# Out:
#   First Name Last Name       Email Address Degree  \
# 0    slakoth    normal  slakoth.normal3945    n/a
# 1     espeon      rock          e.rock7454    n/a
# 2     rhydon     ghost     rhydonghost7966    mba
# 3    porygon     grass        porygong9247     ms
# 4    tangela     grass    tangelagrass1376    n/a
# 5    chansey     steel      c.electric7518    n/a
# 6    blissey     ghost   blissey.ghost4154    n/a
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# ## Convert Country to 3 digit code

# %%
# df_mailchimp.Country = df_mailchimp.Country.apply(mapCountry)
# df_mailchimp

# %% [markdown]
# ## Clean Degree String

# %%
df_mailchimp.Degree = df_mailchimp.Degree.apply(cleanDegreeStr)
df_mailchimp
# Out:
#   First Name Last Name       Email Address Degree  \
# 0    slakoth    normal  slakoth.normal3945    n/a
# 1     espeon      rock          e.rock7454    n/a
# 2     rhydon     ghost     rhydonghost7966    mba
# 3    porygon     grass        porygong9247     ms
# 4    tangela     grass    tangelagrass1376    n/a
# 5    chansey     steel      c.electric7518    n/a
# 6    blissey     ghost   blissey.ghost4154    n/a
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %% [markdown]
# Converting to 3-char country code is time consuming. Reserving that conversion after subsetting

# %% [markdown]
# # Find Best Match for each MailChimp record

# %% [markdown]
# Finding the best match for each mail chimp record is a 3 step process
# - Map the MailChimp record to the Stanford Alumni dataframe
# - Subset the entire dataframe by the first name
# - Calculate the cosine similarity for the resulting subset
#
# Few edge cases to note:
# - Subset by just the first name, in case a user has changed their last name but change their emails or contact info
# - We check for similarity of the 'bounced' MailChimp email handle against *all* possible email fields
# - We check for similarity of the 'bounced' MailChimp country field against *all* possible country fields
#
# The result returned is a dictionary of
# - Dataframe of data in order of score (key: `df`)
# - List of index of records in stanford alumni dataframe in order of score (key: `idx`)
# - List of cosin similarity scores (key: `score`)

# %%
def map_MailChimpData_to_SAA_DF(mc_rec_idx,df_mc=df_mailchimp):
    mc_rec = df_mc.iloc[mc_rec_idx]
    target_dict = {'first_name': mc_rec['First Name'], 
                   'last_name': mc_rec['Last Name'],
                   
                   'home_email_address': mc_rec['Email Address'],
                   'bus_email_address': mc_rec['Email Address'],
                   'email_switch': mc_rec['Email Address'],
                   'saa_email_address': mc_rec['Email Address'],
                   'gsb_email_address': mc_rec['Email Address'],
                   'other_email_address': mc_rec['Email Address'],
                   
                    'home_country': mc_rec['Country'],                   
                    'bus_country': mc_rec['Country'],          
                   
                    'short_degree_string': mc_rec['Degree']
                  
                  }
    df =  pd.DataFrame(target_dict,index=['mc_'+str(mc_rec_idx)])
    return df

# %%
map_MailChimpData_to_SAA_DF(0).iloc[0]
# Out:
# first_name                        slakoth
# last_name                          normal
# home_email_address     slakoth.normal3945
# bus_email_address      slakoth.normal3945
# email_switch           slakoth.normal3945
# saa_email_address      slakoth.normal3945
# gsb_email_address      slakoth.normal3945
# other_email_address    slakoth.normal3945
# home_country                          USA
# bus_country                           USA
# short_degree_string                   n/a
# Name: mc_0, dtype: object

# %%
print(df_mailchimp.shape)
# Out:
# (7, 5)

# %%
results_dict = {}

for i in range(0,df_mailchimp.shape[0]):
    user_dict={}
    #map the data of a mailchimp record to the format in SAA df
    df_mapped_mc_rec = map_MailChimpData_to_SAA_DF(i)
    
    #subsetting the original SAA df by the first name
    df_saa_subset = df_saa[df_saa['first_name'] == df_mapped_mc_rec.iloc[0]['first_name']]
    
    #Concattenating the 2 dataframes together
    df_mc_and_saa_subset = pd.concat([df_mapped_mc_rec,df_saa_subset], axis = 0)
    
    #Changing degree column to vectorized columns
    df_mc_and_saa_subset = parseDegreeCol(df=df_mc_and_saa_subset,deg_colName='short_degree_string')
    
    #Map the country to their 3 digit codes
    df_mc_and_saa_subset.home_country = df_mc_and_saa_subset.home_country.apply(mapCountry)
    df_mc_and_saa_subset.bus_country = df_mc_and_saa_subset.bus_country.apply(mapCountry)
    
    
#     ohe_df = ohe(df_mc_and_saa_subset, df_mc_and_saa_subset.columns)
#     ohe_df.drop(columns = df_mc_and_saa_subset.columns, inplace = True)
    ohe_df = ohe(df_mc_and_saa_subset, df_mc_and_saa_subset.columns)
    ohe_df.drop(columns = df_mc_and_saa_subset.columns, inplace = True)
    y = np.array(ohe_df.iloc[0])
    y = y.reshape(1,-1)
    cos_sim = cosine_similarity(ohe_df, y)
    cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
    results = list(cos_sim.index)
    results_df = df_mc_and_saa_subset.loc[results]
    username = df_mapped_mc_rec.iloc[0]['first_name'] + df_mapped_mc_rec.iloc[0]['last_name']
    user_dict['idx'] = results
    user_dict['cosine_sim_result'] = results_df
    user_dict['SAA_query_result'] = df_saa_original.iloc[results[1:]]
    results_dict[username] = user_dict

# %%
results_dict
# Out:
# {'slakothnormal': {'idx': ['mc_0',
#    1290,
#    1967,
#    74,
#    2052,
#    2353,
#    2709,
#    3789,
#    503,
#    776,
#    1095,
#    1485,
#    2326,
#    2587],
#   'cosine_sim_result':      first_name last_name  home_email_address   bus_email_address  \
#   mc_0    slakoth    normal  slakoth.normal3945  slakoth.normal3945
#   1290    slakoth    normal                 n/a                 n/a
#   1967    slakoth     ghost   slakoth.ghost5782                 n/a
#   74      slakoth    normal  slakoth.normal3945                 n/a
#   2052    slakoth     water        slakothw1017                 n/a
#   2353    slakoth    poison                 n/a        s.poison6761
#   2709    slakoth    dragon         s.dragon440                 n/a
#   3789    slakoth     ghost                 n/a                 n/a
#   503     slakoth      rock                 n/a                 n/a
#   776     slakoth    ground                 n/a                 n/a
#   1095    slakoth  fighting                 n/a                 n/a
#   1485    slakoth    ground          sground648         sground2975
#   2326    slakoth     water                 n/a                 n/a
#   2587    slakoth     grass                 n/a                 n/a
#
#                email_switch   saa_email_address   gsb_email_address  \
#   mc_0   slakoth.normal3945  slakoth.normal3945  slakoth.normal3945
#   1290         s.normal5961                 n/a                 n/a
#   1967          slakothg316          sghost4008                 n/a
#   74                    n/a                 n/a                 n/a
#   2052          slakothw808                 n/a                 n/a
#   2353                  n/a                 n/a                 n/a
#   2709                  n/a         sdragon3285                 n/a
#   3789                  n/a                 n/a                 n/a
#   503             srock5364                 n/a                 n/a
#   776                   n/a                 n/a                 n/a
#   1095  slakothfighting1488       s.fighting883                 n/a
#   1485          sground5309   slakothground1530                 n/a
#   2326          s.water4650                 n/a                 n/a
#   2587                  n/a                 n/a                 n/a
#
#        other_email_address home_country bus_country  ba  bs  jd  ma  mba  md  \
#   mc_0  slakoth.normal3945          USA         USA   0   0   0   0    0   0
#   1290                 n/a          USA         n/a   0   0   0   0    0   0
#   1967                 n/a          USA         n/a   0   0   0   0    0   0
#   74                   n/a          USA         JPN   1   0   0   0    1   0
#   2052                 n/a          KWT         USA   0   0   0   1    0   0
#   2353                 n/a          n/a         USA   0   0   0   0    1   0
#   2709                 n/a          n/a         USA   0   0   0   2    1   0
#   3789                 n/a          JPN         n/a   0   0   0   0    2   0
#   503                  n/a          n/a         CHN   0   1   0   0    0   0
#   776                  n/a          n/a         n/a   1   0   0   0    0   0
#   1095                 n/a          USA         n/a   0   0   1   0    0   1
#   1485                 n/a          n/a         USA   0   0   0   0    0   1
#   2326                 n/a          KWT         CHN   0   0   0   0    1   0
#   2587                 n/a          n/a         CHN   1   0   0   0    0   0
#
#         ms  phd
#   mc_0   0    0
#   1290   0    0
#   1967   0    0
#   74     0    1
#   2052   0    0
#   2353   0    0
#   2709   0    0
#   3789   0    0
#   503    0    0
#   776    0    0
#   1095   0    0
#   1485   1    0
#   2326   0    1
#   2587   0    1  ,
#   'SAA_query_result':       pref_mail_name  pref_class_year home_city home_state_code  \
#   1290             NaN              NaN     Seoul             NaN
#   1967             NaN              NaN    London             NaN
#   74               NaN              NaN     Seoul             NaN
#   2052             NaN              NaN         *               *
#   2353             NaN           2001.0       NaN             NaN
#   2709             NaN              NaN       NaN             NaN
#   3789             NaN              NaN     Tokyo             NaN
#   503              NaN           2018.0   Beijing             NaN
#   776              NaN              NaN     Seoul             NaN
#   1095             NaN              NaN    London             NaN
#   1485             NaN              NaN  Shanghai             NaN
#   2326             NaN              NaN     Seoul             NaN
#   2587             NaN           2014.0     Tokyo             NaN
#
#          home_country  home_phone_area_code home_phone_number  \
#   1290            USA                   NaN      735 1117-916
#   1967  United States                   NaN               NaN
#   74              USA                   NaN                 *
#   2052         Kuwait                   NaN      339 5237-035
#   2353            NaN                   NaN                 *
#   2709            NaN                   NaN               NaN
#   3789          Japan                   NaN      440 3348-239
#   503             NaN                   NaN                 *
#   776             NaN                   NaN               NaN
#   1095            USA                   NaN               NaN
#   1485            NaN                   NaN               NaN
#   2326         Kuwait                   NaN               NaN
#   2587              *                   NaN               NaN
#
#                             home_email_address  bus_city  bus_state_code  \
#   1290                                       *       NaN             NaN
#   1967    slakoth.ghost5782@stanfordalumni.org       NaN             NaN
#   74    slakoth.normal3945@alumni.stanford.edu       NaN             NaN
#   2052                  slakothw1017@gmail.com       NaN             NaN
#   2353                                     NaN       NaN             NaN
#   2709         s.dragon440@alumni.stanford.edu       NaN             NaN
#   3789                                     NaN       NaN             NaN
#   503                                        *       NaN             NaN
#   776                                      NaN       NaN             NaN
#   1095                                       *       NaN             NaN
#   1485           sground648@stanfordalumni.org       NaN             NaN
#   2326                                       *       NaN             NaN
#   2587                                     NaN       NaN             NaN
#
#           bus_country  bus_phone_area_code  bus_phone_number  \
#   1290            NaN                  NaN               NaN
#   1967            NaN                  NaN               NaN
#   74            Japan                  NaN               NaN
#   2052            USA                  NaN               NaN
#   2353            USA                  NaN               NaN
#   2709  United States                  NaN               NaN
#   3789              *                  NaN               NaN
#   503           China                  NaN               NaN
#   776             NaN                  NaN               NaN
#   1095            NaN                  NaN               NaN
#   1485            USA                  NaN               NaN
#   2326          China                  NaN               NaN
#   2587          China                  NaN               NaN
#
#                       bus_email_address first_name last_name  pref_name_sort  \
#   1290                              NaN    Slakoth    Normal             NaN
#   1967                              NaN    Slakoth     Ghost             NaN
#   74                                NaN    Slakoth    Normal             NaN
#   2052                              NaN    Slakoth     Water             NaN
#   2353  s.poison6761@stanfordalumni.org    Slakoth    Poison             NaN
#   2709                              NaN    Slakoth    Dragon             NaN
#   3789                              NaN    Slakoth     Ghost             NaN
#   503                               NaN    Slakoth      Rock             NaN
#   776                               NaN    Slakoth    Ground             NaN
#   1095                              NaN    Slakoth  Fighting             NaN
#   1485   sground2975@stanfordalumni.org    Slakoth    Ground             NaN
#   2326                              NaN    Slakoth     Water             NaN
#   2587                              NaN    Slakoth     Grass             NaN
#
#                             email_switch                     saa_email_address  \
#   1290  s.normal5961@alumni.stanford.edu                                   NaN
#   1967   slakothg316@alumni.stanford.edu         sghost4008@stanfordalumni.org
#   74                                 NaN                                   NaN
#   2052    slakothw808@stanfordalumni.org                                   NaN
#   2353                               NaN                                   NaN
#   2709                               NaN        sdragon3285@stanfordalumni.org
#   3789                               NaN                                   NaN
#   503       srock5364@stanfordalumni.org                                   NaN
#   776                                NaN                                   NaN
#   1095     slakothfighting1488@gmail.com     s.fighting883@alumni.stanford.edu
#   1485    sground5309@stanfordalumni.org  slakothground1530@stanfordalumni.org
#   2326    s.water4650@stanfordalumni.org                                     *
#   2587                               NaN                                   NaN
#
#        gsb_email_address  other_email_address  pref_phone_area_code  \
#   1290               NaN                  NaN                   NaN
#   1967               NaN                  NaN                   NaN
#   74                 NaN                  NaN                   NaN
#   2052               NaN                  NaN                   NaN
#   2353               NaN                  NaN                   NaN
#   2709               NaN                  NaN                   NaN
#   3789               NaN                  NaN                   NaN
#   503                NaN                  NaN                   NaN
#   776                NaN                  NaN                   NaN
#   1095               NaN                  NaN                   NaN
#   1485               NaN                  NaN                   NaN
#   2326               NaN                  NaN                   NaN
#   2587               NaN                  NaN                   NaN
#
#         pref_phone_number  pref_phone_addr_type  memb_status_desc  \
#   1290                NaN                   NaN               NaN
#   1967                NaN                   NaN               NaN
#   74                  NaN                   NaN               NaN
#   2052                NaN                   NaN               NaN
#   2353                NaN                   NaN               NaN
#   2709                NaN                   NaN               NaN
#   3789                NaN                   NaN               NaN
#   503                 NaN                   NaN               NaN
#   776                 NaN                   NaN               NaN
#   1095                NaN                   NaN               NaN
#   1485                NaN                   NaN               NaN
#   2326                NaN                   NaN               NaN
#   2587                NaN                   NaN               NaN
#
#              short_degree_string  parent_degree_string  \
#   1290                       NaN                   NaN
#   1967                       NaN                   NaN
#   74    BA '99, PhD '85, MBA '89                   NaN
#   2052               '98, MA '94                   NaN
#   2353                   MBA '91                   NaN
#   2709   MA '93, MBA '87, MA '98                   NaN
#   3789     MBA '84, MBA '84, '99                   NaN
#   503                     BS '82                   NaN
#   776                     BA '90                   NaN
#   1095       MD '99, '80, JD '88                   NaN
#   1485            MD '80, MS '93                   NaN
#   2326          MBA '84, PhD '96                   NaN
#   2587      PhD '87, BA '83, '99                   NaN
#
#         short_degree_string_spouse  parent_degree_string_spouse  \
#   1290                         NaN                          NaN
#   1967                         NaN                          NaN
#   74                           NaN                          NaN
#   2052                         NaN                          NaN
#   2353                         NaN                          NaN
#   2709                         NaN                          NaN
#   3789                         NaN                          NaN
#   503                          NaN                          NaN
#   776                          NaN                          NaN
#   1095                         NaN                          NaN
#   1485                         NaN                          NaN
#   2326                         NaN                          NaN
#   2587                         NaN                          NaN
#
#         primary_sort_name  plan_name  primary_ind
#   1290                NaN        NaN          NaN
#   1967                NaN        NaN          NaN
#   74                  NaN        NaN          NaN
#   2052                NaN        NaN          NaN
#   2353                NaN        NaN          NaN
#   2709                NaN        NaN          NaN
#   3789                NaN        NaN          NaN
#   503                 NaN        NaN          NaN
#   776                 NaN        NaN          NaN
#   1095                NaN        NaN          NaN
#   1485                NaN        NaN          NaN
#   2326                NaN        NaN          NaN
#   2587                NaN        NaN          NaN  },
#  'espeonrock': {'idx': ['mc_1',
#    2609,
#    2391,
#    2068,
#    780,
#    2569,
#    2422,
#    2282,
#    34,
#    1360,
#    673,
#    589,
#    451,
#    2637,
#    3915,
#    555,
#    2497,
#    57,
#    984,
#    595,
#    2561,
#    72,
#    2014,
#    247],
#   'cosine_sim_result':      first_name last_name home_email_address bus_email_address  \
#   mc_1     espeon      rock         e.rock7454        e.rock7454
#   2609     espeon    ground        e.ground572               n/a
#   2391     espeon    poison                n/a               n/a
#   2068     espeon    normal                n/a               n/a
#   780      espeon  fighting                n/a               n/a
#   2569     espeon    dragon       e.dragon5120               n/a
#   2422     espeon     ghost                n/a               n/a
#   2282     espeon     steel                n/a               n/a
#   34       espeon      rock                n/a               n/a
#   1360     espeon      fire                n/a               n/a
#   673      espeon     steel                n/a               n/a
#   589      espeon      fire    espeon.fire6670               n/a
#   451      espeon    ground                n/a               n/a
#   2637     espeon     grass                n/a               n/a
#   3915     espeon   psychic                n/a               n/a
#   555      espeon      dark                n/a               n/a
#   2497     espeon  fighting                n/a    e.fighting9033
#   57       espeon     water                n/a               n/a
#   984      espeon     steel   espeon.steel2682               n/a
#   595      espeon  electric                n/a               n/a
#   2561     espeon    dragon                n/a               n/a
#   72       espeon     fairy                n/a               n/a
#   2014     espeon       bug                n/a               n/a
#   247      espeon       bug                n/a               n/a
#
#                email_switch saa_email_address gsb_email_address  \
#   mc_1           e.rock7454        e.rock7454        e.rock7454
#   2609                  n/a  espeonground2065               n/a
#   2391                  n/a               n/a               n/a
#   2068          enormal8901               n/a               n/a
#   780         efighting3288       espeonf9799               n/a
#   2569          espeond4788               n/a               n/a
#   2422                  n/a               n/a               n/a
#   2282                  n/a               n/a               n/a
#   34                    n/a               n/a               n/a
#   1360       espeonfire8800               n/a               n/a
#   673                   n/a               n/a               n/a
#   589           espeonf2076               n/a               n/a
#   451                   n/a               n/a               n/a
#   2637     espeon.grass4914       espeong2790               n/a
#   3915                  n/a               n/a               n/a
#   555                   n/a               n/a               n/a
#   2497                  n/a               n/a               n/a
#   57                    n/a  espeon.water9599               n/a
#   984                   n/a               n/a               n/a
#   595   espeon.electric3524     eelectric5496               n/a
#   2561                  n/a      e.dragon5626               n/a
#   72             efairy1074               n/a               n/a
#   2014                  n/a               n/a               n/a
#   247                   n/a               n/a               n/a
#
#        other_email_address home_country bus_country  ba  bs  jd  ma  mba  md  \
#   mc_1          e.rock7454          USA         USA   0   0   0   0    0   0
#   2609                 n/a          USA         CHN   0   0   0   0    0   0
#   2391                 n/a          USA         n/a   0   0   0   0    0   0
#   2068                 n/a          USA         USA   0   0   1   0    0   0
#   780                  n/a          USA         n/a   0   0   1   0    0   0
#   2569                 n/a          USA         KWT   0   0   0   0    0   0
#   2422                 n/a          KWT         JPN   0   0   0   0    0   0
#   2282                 n/a          USA         JPN   0   1   0   0    0   0
#   34                   n/a          KWT         n/a   1   0   0   0    0   0
#   1360                 n/a          n/a         n/a   0   0   0   0    0   0
#   673                  n/a          n/a         n/a   0   0   0   0    0   0
#   589                  n/a          KWT         JPN   1   0   0   0    0   0
#   451                  n/a          n/a         JPN   0   0   0   0    0   0
#   2637                 n/a          JPN         USA   1   0   0   0    0   0
#   3915                 n/a          USA         CHN   0   0   0   0    0   0
#   555                  n/a          n/a         n/a   0   0   0   0    1   1
#   2497                 n/a          n/a         USA   0   0   0   1    0   0
#   57                   n/a          n/a         n/a   0   0   0   1    0   0
#   984                  n/a          JPN         n/a   0   2   0   0    1   0
#   595                  n/a          JPN         n/a   0   0   1   0    0   1
#   2561                 n/a          USA         n/a   0   1   1   0    1   0
#   72                   n/a          n/a         n/a   0   1   0   1    0   0
#   2014                 n/a          n/a         n/a   0   0   1   0    0   1
#   247                  n/a          n/a         n/a   0   0   1   1    0   0
#
#         ms  phd
#   mc_1   0    0
#   2609   0    0
#   2391   0    0
#   2068   0    0
#   780    0    0
#   2569   0    1
#   2422   0    0
#   2282   0    0
#   34     0    0
#   1360   0    0
#   673    0    0
#   589    0    0
#   451    0    1
#   2637   1    0
#   3915   1    1
#   555    0    0
#   2497   1    1
#   57     1    0
#   984    0    0
#   595    0    0
#   2561   0    0
#   72     1    0
#   2014   0    1
#   247    0    1  ,
#   'SAA_query_result':       pref_mail_name  pref_class_year home_city home_state_code  \
#   2609             NaN              NaN     Seoul             NaN
#   2391             NaN              NaN     Dubai             NaN
#   2068             NaN              NaN  Shanghai             NaN
#   780              NaN              NaN    London             NaN
#   2569             NaN           1998.0       NaN             NaN
#   2422             NaN              NaN  Shanghai             NaN
#   2282             NaN              NaN    Madrid             NaN
#   34               NaN              NaN  Shanghai             NaN
#   1360             NaN           2007.0     Seoul             NaN
#   673              NaN              NaN     Seoul             NaN
#   589              NaN           2009.0     Seoul             NaN
#   451              NaN              NaN    Boston              MA
#   2637             NaN              NaN   Chicago              IL
#   3915             NaN              NaN    Boston              MA
#   555              NaN              NaN         *               *
#   2497             NaN           1999.0    London             NaN
#   57               NaN           1998.0     Tokyo             NaN
#   984              NaN              NaN    London             NaN
#   595              NaN           2016.0         *               *
#   2561             NaN           1997.0     Seoul             NaN
#   72               NaN           2015.0     Tokyo             NaN
#   2014             NaN              NaN    London             NaN
#   247              NaN              NaN    Boston              MA
#
#          home_country  home_phone_area_code home_phone_number  \
#   2609            USA                   NaN      351 6165-957
#   2391  United States                   NaN                 *
#   2068            USA                   NaN      652 0672-499
#   780   United States                   NaN      354 8153-398
#   2569            USA                   NaN               NaN
#   2422         Kuwait                   NaN                 *
#   2282  United States                   NaN      550 9995-137
#   34           Kuwait                   NaN                 *
#   1360            NaN                   NaN                 *
#   673             NaN                   NaN      893 1126-455
#   589          Kuwait                   NaN                 *
#   451               *                   NaN               NaN
#   2637          Japan                   NaN                 *
#   3915  United States                   NaN               NaN
#   555               *                   NaN               NaN
#   2497            NaN                   NaN                 *
#   57                *                   NaN               NaN
#   984           Japan                   NaN               NaN
#   595           Japan                   NaN                 *
#   2561  United States                   NaN               NaN
#   72              NaN                   NaN      253 6829-594
#   2014            NaN                   NaN                 *
#   247               *                   NaN               NaN
#
#                         home_email_address  bus_city  bus_state_code  \
#   2609     e.ground572@alumni.stanford.edu       NaN             NaN
#   2391                                   *       NaN             NaN
#   2068                                 NaN       NaN             NaN
#   780                                    *       NaN             NaN
#   2569    e.dragon5120@alumni.stanford.edu       NaN             NaN
#   2422                                   *       NaN             NaN
#   2282                                 NaN       NaN             NaN
#   34                                   NaN       NaN             NaN
#   1360                                   *       NaN             NaN
#   673                                    *       NaN             NaN
#   589   espeon.fire6670@stanfordalumni.org       NaN             NaN
#   451                                    *       NaN             NaN
#   2637                                   *       NaN             NaN
#   3915                                   *       NaN             NaN
#   555                                  NaN       NaN             NaN
#   2497                                 NaN       NaN             NaN
#   57                                     *       NaN             NaN
#   984           espeon.steel2682@gmail.com       NaN             NaN
#   595                                    *       NaN             NaN
#   2561                                   *       NaN             NaN
#   72                                   NaN       NaN             NaN
#   2014                                 NaN       NaN             NaN
#   247                                    *       NaN             NaN
#
#           bus_country  bus_phone_area_code  bus_phone_number  \
#   2609          China                  NaN               NaN
#   2391            NaN                  NaN               NaN
#   2068  United States                  NaN               NaN
#   780             NaN                  NaN               NaN
#   2569         Kuwait                  NaN               NaN
#   2422          Japan                  NaN               NaN
#   2282          Japan                  NaN               NaN
#   34              NaN                  NaN               NaN
#   1360              *                  NaN               NaN
#   673             NaN                  NaN               NaN
#   589           Japan                  NaN               NaN
#   451           Japan                  NaN               NaN
#   2637  United States                  NaN               NaN
#   3915          China                  NaN               NaN
#   555               *                  NaN               NaN
#   2497  United States                  NaN               NaN
#   57              NaN                  NaN               NaN
#   984             NaN                  NaN               NaN
#   595             NaN                  NaN               NaN
#   2561            NaN                  NaN               NaN
#   72              NaN                  NaN               NaN
#   2014              *                  NaN               NaN
#   247             NaN                  NaN               NaN
#
#                         bus_email_address first_name last_name  pref_name_sort  \
#   2609                                NaN     Espeon    Ground             NaN
#   2391                                NaN     Espeon    Poison             NaN
#   2068                                NaN     Espeon    Normal             NaN
#   780                                 NaN     Espeon  Fighting             NaN
#   2569                                NaN     Espeon    Dragon             NaN
#   2422                                NaN     Espeon     Ghost             NaN
#   2282                                NaN     Espeon     Steel             NaN
#   34                                  NaN     Espeon      Rock             NaN
#   1360                                NaN     Espeon      Fire             NaN
#   673                                 NaN     Espeon     Steel             NaN
#   589                                 NaN     Espeon      Fire             NaN
#   451                                 NaN     Espeon    Ground             NaN
#   2637                                NaN     Espeon     Grass             NaN
#   3915                                NaN     Espeon   Psychic             NaN
#   555                                 NaN     Espeon      Dark             NaN
#   2497  e.fighting9033@stanfordalumni.org     Espeon  Fighting             NaN
#   57                                  NaN     Espeon     Water             NaN
#   984                                 NaN     Espeon     Steel             NaN
#   595                                 NaN     Espeon  Electric             NaN
#   2561                                NaN     Espeon    Dragon             NaN
#   72                                  NaN     Espeon     Fairy             NaN
#   2014                                NaN     Espeon       Bug             NaN
#   247                                 NaN     Espeon       Bug             NaN
#
#                                   email_switch  \
#   2609                                     NaN
#   2391                                     NaN
#   2068                   enormal8901@gmail.com
#   780        efighting3288@alumni.stanford.edu
#   2569         espeond4788@alumni.stanford.edu
#   2422                                     NaN
#   2282                                     NaN
#   34                                       NaN
#   1360                espeonfire8800@gmail.com
#   673                                      NaN
#   589          espeonf2076@alumni.stanford.edu
#   451                                      NaN
#   2637     espeon.grass4914@stanfordalumni.org
#   3915                                     NaN
#   555                                      NaN
#   2497                                     NaN
#   57                                       NaN
#   984                                      NaN
#   595   espeon.electric3524@stanfordalumni.org
#   2561                                     NaN
#   72                      efairy1074@gmail.com
#   2014                                     NaN
#   247                                      NaN
#
#                            saa_email_address gsb_email_address  \
#   2609  espeonground2065@alumni.stanford.edu               NaN
#   2391                                   NaN               NaN
#   2068                                     *               NaN
#   780         espeonf9799@stanfordalumni.org               NaN
#   2569                                     *               NaN
#   2422                                     *               NaN
#   2282                                     *               NaN
#   34                                     NaN               NaN
#   1360                                     *               NaN
#   673                                      *               NaN
#   589                                    NaN               NaN
#   451                                    NaN               NaN
#   2637        espeong2790@stanfordalumni.org               NaN
#   3915                                     *               NaN
#   555                                      *               NaN
#   2497                                     *               NaN
#   57    espeon.water9599@alumni.stanford.edu               NaN
#   984                                      *               NaN
#   595       eelectric5496@stanfordalumni.org               NaN
#   2561       e.dragon5626@stanfordalumni.org               NaN
#   72                                       *               NaN
#   2014                                     *               NaN
#   247                                      *               NaN
#
#         other_email_address  pref_phone_area_code  pref_phone_number  \
#   2609                  NaN                   NaN                NaN
#   2391                  NaN                   NaN                NaN
#   2068                  NaN                   NaN                NaN
#   780                   NaN                   NaN                NaN
#   2569                  NaN                   NaN                NaN
#   2422                  NaN                   NaN                NaN
#   2282                  NaN                   NaN                NaN
#   34                    NaN                   NaN                NaN
#   1360                  NaN                   NaN                NaN
#   673                   NaN                   NaN                NaN
#   589                   NaN                   NaN                NaN
#   451                   NaN                   NaN                NaN
#   2637                  NaN                   NaN                NaN
#   3915                  NaN                   NaN                NaN
#   555                   NaN                   NaN                NaN
#   2497                  NaN                   NaN                NaN
#   57                    NaN                   NaN                NaN
#   984                   NaN                   NaN                NaN
#   595                   NaN                   NaN                NaN
#   2561                  NaN                   NaN                NaN
#   72                    NaN                   NaN                NaN
#   2014                  NaN                   NaN                NaN
#   247                   NaN                   NaN                NaN
#
#         pref_phone_addr_type  memb_status_desc      short_degree_string  \
#   2609                   NaN               NaN                      NaN
#   2391                   NaN               NaN                      NaN
#   2068                   NaN               NaN                   JD '98
#   780                    NaN               NaN                   JD '95
#   2569                   NaN               NaN                  PhD '94
#   2422                   NaN               NaN                      NaN
#   2282                   NaN               NaN                   BS '95
#   34                     NaN               NaN                   BA '86
#   1360                   NaN               NaN                      NaN
#   673                    NaN               NaN                      NaN
#   589                    NaN               NaN                   BA '84
#   451                    NaN               NaN                  PhD '93
#   2637                   NaN               NaN      BA '97, '81, MS '98
#   3915                   NaN               NaN          PhD '97, MS '89
#   555                    NaN               NaN          MBA '88, MD '85
#   2497                   NaN               NaN  MS '96, PhD '90, MA '90
#   57                     NaN               NaN           MS '84, MA '94
#   984                    NaN               NaN  BS '88, MBA '96, BS '99
#   595                    NaN               NaN           MD '92, JD '85
#   2561                   NaN               NaN  MBA '80, BS '93, JD '91
#   72                     NaN               NaN   MS '95, BS '83, MA '97
#   2014                   NaN               NaN  JD '83, MD '80, PhD '86
#   247                    NaN               NaN  MA '92, PhD '87, JD '92
#
#         parent_degree_string  short_degree_string_spouse  \
#   2609                   NaN                         NaN
#   2391                   NaN                         NaN
#   2068                   NaN                         NaN
#   780                    NaN                         NaN
#   2569                   NaN                         NaN
#   2422                   NaN                         NaN
#   2282                   NaN                         NaN
#   34                     NaN                         NaN
#   1360                   NaN                         NaN
#   673                    NaN                         NaN
#   589                    NaN                         NaN
#   451                    NaN                         NaN
#   2637                   NaN                         NaN
#   3915                   NaN                         NaN
#   555                    NaN                         NaN
#   2497                   NaN                         NaN
#   57                     NaN                         NaN
#   984                    NaN                         NaN
#   595                    NaN                         NaN
#   2561                   NaN                         NaN
#   72                     NaN                         NaN
#   2014                   NaN                         NaN
#   247                    NaN                         NaN
#
#         parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind
#   2609                          NaN                NaN        NaN          NaN
#   2391                          NaN                NaN        NaN          NaN
#   2068                          NaN                NaN        NaN          NaN
#   780                           NaN                NaN        NaN          NaN
#   2569                          NaN                NaN        NaN          NaN
#   2422                          NaN                NaN        NaN          NaN
#   2282                          NaN                NaN        NaN          NaN
#   34                            NaN                NaN        NaN          NaN
#   1360                          NaN                NaN        NaN          NaN
#   673                           NaN                NaN        NaN          NaN
#   589                           NaN                NaN        NaN          NaN
#   451                           NaN                NaN        NaN          NaN
#   2637                          NaN                NaN        NaN          NaN
#   3915                          NaN                NaN        NaN          NaN
#   555                           NaN                NaN        NaN          NaN
#   2497                          NaN                NaN        NaN          NaN
#   57                            NaN                NaN        NaN          NaN
#   984                           NaN                NaN        NaN          NaN
#   595                           NaN                NaN        NaN          NaN
#   2561                          NaN                NaN        NaN          NaN
#   72                            NaN                NaN        NaN          NaN
#   2014                          NaN                NaN        NaN          NaN
#   247                           NaN                NaN        NaN          NaN  },
#  'rhydonghost': {'idx': ['mc_2',
#    1929,
#    3267,
#    1170,
#    1235,
#    1309,
#    30,
#    728,
#    1332,
#    1606,
#    3066],
#   'cosine_sim_result':      first_name last_name home_email_address bus_email_address  \
#   mc_2     rhydon     ghost    rhydonghost7966   rhydonghost7966
#   1929     rhydon       ice                n/a               n/a
#   3267     rhydon     steel                n/a               n/a
#   1170     rhydon  electric                n/a               n/a
#   1235     rhydon     water    rhydonwater7742               n/a
#   1309     rhydon    poison  rhydon.poison8602               n/a
#   30       rhydon     ghost                n/a        rghost7875
#   728      rhydon       ice                n/a               n/a
#   1332     rhydon    poison                n/a               n/a
#   1606     rhydon  electric                n/a               n/a
#   3066     rhydon      rock                n/a               n/a
#
#               email_switch saa_email_address gsb_email_address  \
#   mc_2     rhydonghost7966   rhydonghost7966   rhydonghost7966
#   1929           r.ice1330               n/a               n/a
#   3267                 n/a               n/a               n/a
#   1170      r.electric5222               n/a               n/a
#   1235                 n/a               n/a               n/a
#   1309         rpoison1424               n/a               n/a
#   30      rhydon.ghost5916   rhydonghost4158               n/a
#   728                  n/a               n/a               n/a
#   1332                 n/a               n/a               n/a
#   1606  rhydon.electric871               n/a               n/a
#   3066                 n/a         rrock2774               n/a
#
#        other_email_address home_country bus_country  ba  bs  jd  ma  mba  md  \
#   mc_2     rhydonghost7966          USA         USA   0   0   0   0    1   0
#   1929                 n/a          USA         USA   1   0   0   2    0   0
#   3267                 n/a          n/a         KWT   0   0   0   0    0   0
#   1170                 n/a          n/a         n/a   0   0   1   0    1   0
#   1235                 n/a          KWT         CHN   0   0   1   0    1   0
#   1309                 n/a          n/a         n/a   0   0   0   0    0   0
#   30                   n/a          JPN         CHN   0   0   0   1    0   0
#   728                  n/a          JPN         KWT   0   0   1   0    1   1
#   1332                 n/a          USA         CHN   0   0   0   1    0   1
#   1606                 n/a          USA         CHN   0   0   1   0    0   2
#   3066                 n/a          CHN         n/a   0   1   0   0    0   0
#
#         ms  phd
#   mc_2   0    0
#   1929   0    0
#   3267   0    0
#   1170   0    0
#   1235   0    0
#   1309   0    0
#   30     1    0
#   728    0    0
#   1332   0    0
#   1606   0    0
#   3066   0    1  ,
#   'SAA_query_result':       pref_mail_name  pref_class_year home_city home_state_code  \
#   1929             NaN              NaN  Shanghai             NaN
#   3267             NaN              NaN   Chicago              IL
#   1170             NaN           1991.0       NaN             NaN
#   1235             NaN           1995.0   Beijing             NaN
#   1309             NaN              NaN   Beijing             NaN
#   30               NaN           1998.0       NaN             NaN
#   728              NaN              NaN  Shanghai             NaN
#   1332             NaN              NaN    London             NaN
#   1606             NaN              NaN    London             NaN
#   3066             NaN              NaN       NaN             NaN
#
#          home_country  home_phone_area_code home_phone_number  \
#   1929  United States                   NaN               NaN
#   3267            NaN                   NaN               NaN
#   1170            NaN                   NaN               NaN
#   1235         Kuwait                   NaN               NaN
#   1309              *                   NaN                 *
#   30            Japan                   NaN               NaN
#   728           Japan                   NaN               NaN
#   1332  United States                   NaN                 *
#   1606            USA                   NaN               NaN
#   3066          China                   NaN      638 4861-002
#
#                  home_email_address  bus_city  bus_state_code    bus_country  \
#   1929                          NaN       NaN             NaN  United States
#   3267                            *       NaN             NaN         Kuwait
#   1170                            *       NaN             NaN            NaN
#   1235    rhydonwater7742@gmail.com       NaN             NaN          China
#   1309  rhydon.poison8602@gmail.com       NaN             NaN            NaN
#   30                              *       NaN             NaN          China
#   728                             *       NaN             NaN         Kuwait
#   1332                          NaN       NaN             NaN          China
#   1606                            *       NaN             NaN          China
#   3066                            *       NaN             NaN            NaN
#
#         bus_phone_area_code  bus_phone_number               bus_email_address  \
#   1929                  NaN               NaN                             NaN
#   3267                  NaN               NaN                             NaN
#   1170                  NaN               NaN                             NaN
#   1235                  NaN               NaN                             NaN
#   1309                  NaN               NaN                             NaN
#   30                    NaN               NaN  rghost7875@alumni.stanford.edu
#   728                   NaN               NaN                             NaN
#   1332                  NaN               NaN                             NaN
#   1606                  NaN               NaN                             NaN
#   3066                  NaN               NaN                             NaN
#
#        first_name last_name  pref_name_sort  \
#   1929     Rhydon       Ice             NaN
#   3267     Rhydon     Steel             NaN
#   1170     Rhydon  Electric             NaN
#   1235     Rhydon     Water             NaN
#   1309     Rhydon    Poison             NaN
#   30       Rhydon     Ghost             NaN
#   728      Rhydon       Ice             NaN
#   1332     Rhydon    Poison             NaN
#   1606     Rhydon  Electric             NaN
#   3066     Rhydon      Rock             NaN
#
#                                 email_switch  \
#   1929          r.ice1330@stanfordalumni.org
#   3267                                   NaN
#   1170    r.electric5222@alumni.stanford.edu
#   1235                                   NaN
#   1309       rpoison1424@alumni.stanford.edu
#   30    rhydon.ghost5916@alumni.stanford.edu
#   728                                    NaN
#   1332                                   NaN
#   1606          rhydon.electric871@gmail.com
#   3066                                   NaN
#
#                           saa_email_address gsb_email_address  \
#   1929                                    *               NaN
#   3267                                  NaN               NaN
#   1170                                    *               NaN
#   1235                                  NaN               NaN
#   1309                                  NaN               NaN
#   30    rhydonghost4158@alumni.stanford.edu               NaN
#   728                                   NaN               NaN
#   1332                                    *               NaN
#   1606                                  NaN               NaN
#   3066        rrock2774@alumni.stanford.edu               NaN
#
#         other_email_address  pref_phone_area_code  pref_phone_number  \
#   1929                  NaN                   NaN                NaN
#   3267                  NaN                   NaN                NaN
#   1170                  NaN                   NaN                NaN
#   1235                  NaN                   NaN                NaN
#   1309                  NaN                   NaN                NaN
#   30                    NaN                   NaN                NaN
#   728                   NaN                   NaN                NaN
#   1332                  NaN                   NaN                NaN
#   1606                  NaN                   NaN                NaN
#   3066                  NaN                   NaN                NaN
#
#         pref_phone_addr_type  memb_status_desc      short_degree_string  \
#   1929                   NaN               NaN   MA '94, MA '80, BA '89
#   3267                   NaN               NaN                      NaN
#   1170                   NaN               NaN          JD '88, MBA '86
#   1235                   NaN               NaN          MBA '83, JD '99
#   1309                   NaN               NaN                      NaN
#   30                     NaN               NaN      MA '91, MS '93, '95
# ...
#   618                           NaN                NaN        NaN          NaN
#   1143                          NaN                NaN        NaN          NaN
#   2200                          NaN                NaN        NaN          NaN
#   3742                          NaN                NaN        NaN          NaN
#   259                           NaN                NaN        NaN          NaN
#   2242                          NaN                NaN        NaN          NaN
#   2307                          NaN                NaN        NaN          NaN
#   2374                          NaN                NaN        NaN          NaN
#   2866                          NaN                NaN        NaN          NaN  },
#  'blisseyghost': {'idx': ['mc_6',
#    600,
#    754,
#    802,
#    1600,
#    2402,
#    390,
#    850,
#    977,
#    1430,
#    1648,
#    1935,
#    858,
#    1545,
#    3811],
#   'cosine_sim_result':      first_name last_name home_email_address  bus_email_address  \
#   mc_6    blissey     ghost  blissey.ghost4154  blissey.ghost4154
#   600     blissey     ghost                n/a                n/a
#   754     blissey      rock                n/a                n/a
#   802     blissey     steel                n/a                n/a
#   1600    blissey    dragon                n/a                n/a
#   2402    blissey       ice           bice5800                n/a
#   390     blissey     fairy         bfairy6293                n/a
#   850     blissey       ice                n/a                n/a
#   977     blissey       ice                n/a                n/a
#   1430    blissey      rock                n/a                n/a
#   1648    blissey      fire        blisseyf465                n/a
#   1935    blissey     water                n/a    blisseywater628
#   858     blissey      rock                n/a   blissey.rock4438
#   1545    blissey      dark       blisseyd5981                n/a
#   3811    blissey    poison                n/a                n/a
#
#              email_switch  saa_email_address  gsb_email_address  \
#   mc_6  blissey.ghost4154  blissey.ghost4154  blissey.ghost4154
#   600   blissey.ghost4154                n/a                n/a
#   754        blisseyr2075                n/a                n/a
#   802        blisseys3334                n/a                n/a
#   1600                n/a        bdragon9208                n/a
#   2402                n/a    blissey.ice4795                n/a
#   390        blisseyf5884                n/a                n/a
#   850            bice9725           bice7796                n/a
#   977        blisseyi5337                n/a          b.ice9706
#   1430                n/a                n/a                n/a
#   1648                n/a                n/a                n/a
#   1935        b.water9408         bwater5537                n/a
#   858        blisseyr3225                n/a                n/a
#   1545                n/a                n/a                n/a
#   3811                n/a                n/a                n/a
#
#        other_email_address home_country bus_country  bs  jd  ma  mba  md  ms  \
#   mc_6   blissey.ghost4154          MAC         MAC   0   0   0    0   0   0
#   600                  n/a          USA         n/a   0   0   0    0   0   0
#   754                  n/a          CHN         n/a   0   0   0    0   0   0
#   802                  n/a          KWT         n/a   0   0   0    0   0   0
#   1600                 n/a          JPN         USA   0   0   0    0   0   0
#   2402                 n/a          KWT         CHN   1   0   0    0   0   0
#   390                  n/a          KWT         n/a   0   0   0    1   0   0
#   850                  n/a          JPN         KWT   0   0   0    0   0   1
#   977                  n/a          CHN         KWT   0   0   0    0   0   1
#   1430                 n/a          USA         KWT   0   0   0    0   0   0
#   1648                 n/a          USA         JPN   0   0   0    0   0   1
#   1935                 n/a          JPN         JPN   0   0   1    0   0   0
#   858                  n/a          n/a         USA   0   0   1    0   0   0
#   1545                 n/a          KWT         USA   0   1   1    0   0   0
#   3811                 n/a          n/a         USA   1   0   0    0   1   0
#
#         phd
#   mc_6    0
#   600     0
#   754     0
#   802     0
#   1600    0
#   2402    0
#   390     0
#   850     0
#   977     0
#   1430    1
#   1648    0
#   1935    1
#   858     1
#   1545    0
#   3811    1  ,
#   'SAA_query_result':       pref_mail_name  pref_class_year home_city home_state_code home_country  \
#   600              NaN              NaN     Dubai             NaN          USA
#   754              NaN           2011.0         *               *        China
#   802              NaN           2017.0     Seoul             NaN       Kuwait
#   1600             NaN              NaN       NaN             NaN        Japan
#   2402             NaN           2001.0     Seoul             NaN       Kuwait
#   390              NaN              NaN   Chicago              IL       Kuwait
#   850              NaN           1995.0     Tokyo             NaN        Japan
#   977              NaN              NaN       NaN             NaN        China
#   1430             NaN              NaN    London             NaN          USA
#   1648             NaN              NaN   Beijing             NaN          USA
#   1935             NaN              NaN       NaN             NaN        Japan
#   858              NaN              NaN   Beijing             NaN            *
#   1545             NaN           2000.0       NaN             NaN       Kuwait
#   3811             NaN              NaN   Beijing             NaN          NaN
#
#         home_phone_area_code home_phone_number               home_email_address  \
#   600                    NaN                 *                              NaN
#   754                    NaN               NaN                                *
#   802                    NaN                 *                              NaN
#   1600                   NaN                 *                                *
#   2402                   NaN      611 7404-598               bice5800@gmail.com
#   390                    NaN               NaN    bfairy6293@stanfordalumni.org
#   850                    NaN                 *                              NaN
#   977                    NaN                 *                              NaN
#   1430                   NaN      639 3158-644                                *
#   1648                   NaN               NaN  blisseyf465@alumni.stanford.edu
#   1935                   NaN               NaN                              NaN
#   858                    NaN               NaN                                *
#   1545                   NaN                 *           blisseyd5981@gmail.com
#   3811                   NaN               NaN                              NaN
#
#         bus_city  bus_state_code    bus_country  bus_phone_area_code  \
#   600        NaN             NaN            NaN                  NaN
#   754        NaN             NaN              *                  NaN
#   802        NaN             NaN              *                  NaN
#   1600       NaN             NaN  United States                  NaN
#   2402       NaN             NaN          China                  NaN
#   390        NaN             NaN            NaN                  NaN
#   850        NaN             NaN         Kuwait                  NaN
#   977        NaN             NaN         Kuwait                  NaN
#   1430       NaN             NaN         Kuwait                  NaN
#   1648       NaN             NaN          Japan                  NaN
#   1935       NaN             NaN          Japan                  NaN
#   858        NaN             NaN  United States                  NaN
#   1545       NaN             NaN  United States                  NaN
#   3811       NaN             NaN  United States                  NaN
#
#         bus_phone_number                     bus_email_address first_name  \
#   600                NaN                                   NaN    Blissey
#   754                NaN                                   NaN    Blissey
#   802                NaN                                   NaN    Blissey
#   1600               NaN                                   NaN    Blissey
#   2402               NaN                                   NaN    Blissey
#   390                NaN                                   NaN    Blissey
#   850                NaN                                   NaN    Blissey
#   977                NaN                                   NaN    Blissey
#   1430               NaN                                   NaN    Blissey
#   1648               NaN                                   NaN    Blissey
#   1935               NaN   blisseywater628@alumni.stanford.edu    Blissey
#   858                NaN  blissey.rock4438@alumni.stanford.edu    Blissey
#   1545               NaN                                   NaN    Blissey
#   3811               NaN                                   NaN    Blissey
#
#        last_name  pref_name_sort                           email_switch  \
#   600      Ghost             NaN  blissey.ghost4154@alumni.stanford.edu
#   754       Rock             NaN        blisseyr2075@stanfordalumni.org
#   802      Steel             NaN        blisseys3334@stanfordalumni.org
#   1600    Dragon             NaN                                    NaN
#   2402       Ice             NaN                                    NaN
#   390      Fairy             NaN                 blisseyf5884@gmail.com
#   850        Ice             NaN                     bice9725@gmail.com
#   977        Ice             NaN        blisseyi5337@stanfordalumni.org
#   1430      Rock             NaN                                    NaN
#   1648      Fire             NaN                                    NaN
#   1935     Water             NaN        b.water9408@alumni.stanford.edu
#   858       Rock             NaN        blisseyr3225@stanfordalumni.org
#   1545      Dark             NaN                                    NaN
#   3811    Poison             NaN                                    NaN
#
#                           saa_email_address              gsb_email_address  \
#   600                                     *                            NaN
#   754                                   NaN                            NaN
#   802                                     *                            NaN
#   1600       bdragon9208@stanfordalumni.org                            NaN
#   2402  blissey.ice4795@alumni.stanford.edu                            NaN
#   390                                   NaN                            NaN
#   850           bice7796@stanfordalumni.org                            NaN
#   977                                     *  b.ice9706@alumni.stanford.edu
#   1430                                  NaN                            NaN
#   1648                                    *                            NaN
#   1935        bwater5537@stanfordalumni.org                            NaN
#   858                                     *                            NaN
#   1545                                    *                            NaN
#   3811                                  NaN                            NaN
#
#         other_email_address  pref_phone_area_code  pref_phone_number  \
#   600                   NaN                   NaN                NaN
#   754                   NaN                   NaN                NaN
#   802                   NaN                   NaN                NaN
#   1600                  NaN                   NaN                NaN
#   2402                  NaN                   NaN                NaN
#   390                   NaN                   NaN                NaN
#   850                   NaN                   NaN                NaN
#   977                   NaN                   NaN                NaN
#   1430                  NaN                   NaN                NaN
#   1648                  NaN                   NaN                NaN
#   1935                  NaN                   NaN                NaN
#   858                   NaN                   NaN                NaN
#   1545                  NaN                   NaN                NaN
#   3811                  NaN                   NaN                NaN
#
#         pref_phone_addr_type  memb_status_desc      short_degree_string  \
#   600                    NaN               NaN                      NaN
#   754                    NaN               NaN                      NaN
#   802                    NaN               NaN                      NaN
#   1600                   NaN               NaN                      NaN
#   2402                   NaN               NaN                   BS '90
#   390                    NaN               NaN                  MBA '91
#   850                    NaN               NaN              '95, MS '86
#   977                    NaN               NaN                   MS '94
#   1430                   NaN               NaN                  PhD '90
#   1648                   NaN               NaN                   MS '98
#   1935                   NaN               NaN     PhD '95, '92, MA '84
#   858                    NaN               NaN          MA '97, PhD '94
#   1545                   NaN               NaN           JD '97, MA '87
#   3811                   NaN               NaN  BS '89, PhD '89, MD '86
#
#         parent_degree_string  short_degree_string_spouse  \
#   600                    NaN                         NaN
#   754                    NaN                         NaN
#   802                    NaN                         NaN
#   1600                   NaN                         NaN
#   2402                   NaN                         NaN
#   390                    NaN                         NaN
#   850                    NaN                         NaN
#   977                    NaN                         NaN
#   1430                   NaN                         NaN
#   1648                   NaN                         NaN
#   1935                   NaN                         NaN
#   858                    NaN                         NaN
#   1545                   NaN                         NaN
#   3811                   NaN                         NaN
#
#         parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind
#   600                           NaN                NaN        NaN          NaN
#   754                           NaN                NaN        NaN          NaN
#   802                           NaN                NaN        NaN          NaN
#   1600                          NaN                NaN        NaN          NaN
#   2402                          NaN                NaN        NaN          NaN
#   390                           NaN                NaN        NaN          NaN
#   850                           NaN                NaN        NaN          NaN
#   977                           NaN                NaN        NaN          NaN
#   1430                          NaN                NaN        NaN          NaN
#   1648                          NaN                NaN        NaN          NaN
#   1935                          NaN                NaN        NaN          NaN
#   858                           NaN                NaN        NaN          NaN
#   1545                          NaN                NaN        NaN          NaN
#   3811                          NaN                NaN        NaN          NaN  }}

# %%
df_saa_original = pd.read_excel('./data/SAA_Pokemon_FakeDB.xlsx')
df_saa_original
# Out:
#       pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 0                NaN           2004.0  Shanghai             NaN            *
# 1                NaN              NaN    Madrid             NaN        China
# 2                NaN              NaN     Seoul             NaN       Kuwait
# 3                NaN              NaN    London             NaN          NaN
# 4                NaN              NaN    London             NaN          USA
# ...              ...              ...       ...             ...          ...
# 3995             NaN              NaN    Boston              MA        Japan
# 3996             NaN           2000.0  Shanghai             NaN          NaN
# 3997             NaN              NaN       NaN             NaN       Kuwait
# 3998             NaN              NaN       NaN             NaN        Japan
# 3999             NaN              NaN    Boston              MA          USA
#
#       home_phone_area_code home_phone_number  \
# 0                      NaN                 *
# 1                      NaN               NaN
# 2                      NaN               NaN
# 3                      NaN                 *
# 4                      NaN      775 0678-214
# ...                    ...               ...
# 3995                   NaN               NaN
# 3996                   NaN                 *
# 3997                   NaN               NaN
# 3998                   NaN               NaN
# 3999                   NaN               NaN
#
#                                home_email_address  bus_city  bus_state_code  \
# 0                                             NaN       NaN             NaN
# 1                  weedleg4046@stanfordalumni.org       NaN             NaN
# 2     aerodactyl.electric2974@alumni.stanford.edu       NaN             NaN
# 3                                               *       NaN             NaN
# 4                                               *       NaN             NaN
# ...                                           ...       ...             ...
# 3995                                            *       NaN             NaN
# 3996        kabutops.steel1285@stanfordalumni.org       NaN             NaN
# 3997                                            *       NaN             NaN
# 3998     larvitar.electric9778@stanfordalumni.org       NaN             NaN
# 3999                                            *       NaN             NaN
#
#         bus_country  bus_phone_area_code  bus_phone_number  \
# 0               NaN                  NaN               NaN
# 1             China                  NaN               NaN
# 2            Kuwait                  NaN               NaN
# 3             Japan                  NaN               NaN
# 4               NaN                  NaN               NaN
# ...             ...                  ...               ...
# 3995            NaN                  NaN               NaN
# 3996          China                  NaN               NaN
# 3997            NaN                  NaN               NaN
# 3998  United States                  NaN               NaN
# 3999         Kuwait                  NaN               NaN
#
#          bus_email_address  first_name last_name  pref_name_sort  \
# 0                      NaN   Growlithe       Ice             NaN
# 1                      NaN      Weedle     Grass             NaN
# 2                      NaN  Aerodactyl  Electric             NaN
# 3                      NaN      Pinsir      Fire             NaN
# 4                      NaN      Horsea       Ice             NaN
# ...                    ...         ...       ...             ...
# 3995                   NaN    Smeargle  Electric             NaN
# 3996                   NaN    Kabutops     Steel             NaN
# 3997                   NaN    Slowking    Dragon             NaN
# 3998                   NaN    Larvitar  Electric             NaN
# 3999  u.dark7601@gmail.com    Ursaring      Dark             NaN
#
#                            email_switch                     saa_email_address  \
# 0                                   NaN                                     *
# 1                                   NaN       w.grass5053@alumni.stanford.edu
# 2                                   NaN                                     *
# 3              pinsirfire4582@gmail.com                                     *
# 4           hice7313@stanfordalumni.org                                   NaN
# ...                                 ...                                   ...
# 3995     smeargleelectric9444@gmail.com                                     *
# 3996    k.steel5317@alumni.stanford.edu                                   NaN
# 3997                                NaN      slowkingd5563@stanfordalumni.org
# 3998  l.electric7920@stanfordalumni.org                                   NaN
# 3999      u.dark1814@stanfordalumni.org  ursaring.dark7398@stanfordalumni.org
#
#      gsb_email_address  other_email_address  pref_phone_area_code  \
# 0                  NaN                  NaN                   NaN
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                  NaN                  NaN                   NaN
# ...                ...                  ...                   ...
# 3995               NaN                  NaN                   NaN
# 3996               NaN                  NaN                   NaN
# 3997               NaN                  NaN                   NaN
# 3998               NaN                  NaN                   NaN
# 3999               NaN                  NaN                   NaN
#
#       pref_phone_number  pref_phone_addr_type  memb_status_desc  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
# ...                 ...                   ...               ...
# 3995                NaN                   NaN               NaN
# 3996                NaN                   NaN               NaN
# 3997                NaN                   NaN               NaN
# 3998                NaN                   NaN               NaN
# 3999                NaN                   NaN               NaN
#
#        short_degree_string  parent_degree_string  short_degree_string_spouse  \
# 0                      NaN                   NaN                         NaN
# 1                      '82                   NaN                         NaN
# 2                      NaN                   NaN                         NaN
# 3          JD '94, PhD '97                   NaN                         NaN
# 4                      NaN                   NaN                         NaN
# ...                    ...                   ...                         ...
# 3995      PhD '96, MBA '87                   NaN                         NaN
# 3996                BS '93                   NaN                         NaN
# 3997       PhD '84, JD '93                   NaN                         NaN
# 3998  MBA '92, '98, JD '86                   NaN                         NaN
# 3999       BS '94, PhD '97                   NaN                         NaN
#
#       parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind
# 0                             NaN                NaN        NaN          NaN
# 1                             NaN                NaN        NaN          NaN
# 2                             NaN                NaN        NaN          NaN
# 3                             NaN                NaN        NaN          NaN
# 4                             NaN                NaN        NaN          NaN
# ...                           ...                ...        ...          ...
# 3995                          NaN                NaN        NaN          NaN
# 3996                          NaN                NaN        NaN          NaN
# 3997                          NaN                NaN        NaN          NaN
# 3998                          NaN                NaN        NaN          NaN
# 3999                          NaN                NaN        NaN          NaN
#
# [4000 rows x 32 columns]

# %%
results_dict = {}
for i in range(0,df_mailchimp.shape[1]+1):
#     target = mailchimp_poke2.iloc[i]
#     target_dict = {'first_name': [target[1]], 'last_name': [target[2]],\
#                emails[0]: [target[0]],\
#                emails[1]: [target[0]],\
#                emails[2]: [target[0]],\
#                emails[3]: [target[0]],\
#                emails[4]: [target[0]],\
#                emails[5]: [target[0]],\
#                    handles[0]: [target[4]],\
#                    handles[1]: [target[4]],\
#                    handles[2]: [target[4]],\
#                    handles[3]: [target[4]],\
#                    handles[4]: [target[4]],\
#                    handles[5]: [target[4]],\
#                'home_country': [target[3]]}
#     df = pd.DataFrame.from_dict(target_dict)
#     subset_saa = saa_poke2[saa_poke2['first_name'] == df.loc[0,'first_name']] 
    #the 0 is calling for row, so it does not return a series
#     subset_saa_new = pd.concat([df,subset_saa], axis = 0)
    ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
    ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
    y = np.array(ohe_df.iloc[0])
    y = y.reshape(1,-1)
    cos_sim = cosine_similarity(ohe_df, y)
    cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
    results = list(cos_sim.index)
    results_df = subset_saa_new.loc[results]
    results_dict[i] = results_df

# %%
# saa_poke2.fillna(value='Not Available', inplace=True)
# emails = ['home_email_address', 'bus_email_address', 'email_switch', 'saa_email_address',\
#          'gsb_email_address', 'other_email_address']
# handles = []
# for x in emails:
#     for i in range(0,saa_poke2.shape[0]):
#         if '@' in saa_poke2[x][i]:
#             saa_poke2[x+'_handle'] = saa_poke2[x].str.split('@').str[0]
#         else:
#             saa_poke2[x+'_handle'] = saa_poke2[x]

# %% [markdown]
# ## Function

# %%
results_dict = {}
for i in range(0,df_mailchimp.shape[1]+1):
    target = mailchimp_poke2.iloc[i]
    target_dict = {'first_name': [target[1]], 'last_name': [target[2]],\
               emails[0]: [target[0]],\
               emails[1]: [target[0]],\
               emails[2]: [target[0]],\
               emails[3]: [target[0]],\
               emails[4]: [target[0]],\
               emails[5]: [target[0]],\
                   handles[0]: [target[4]],\
                   handles[1]: [target[4]],\
                   handles[2]: [target[4]],\
                   handles[3]: [target[4]],\
                   handles[4]: [target[4]],\
                   handles[5]: [target[4]],\
               'home_country': [target[3]]}
    df = pd.DataFrame.from_dict(target_dict)
    subset_saa = saa_poke2[saa_poke2['first_name'] == df.loc[0,'first_name']] 
    #the 0 is calling for row, so it does not return a series
    subset_saa_new = pd.concat([df,subset_saa], axis = 0)
    ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
    ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
    y = np.array(ohe_df.iloc[0])
    y = y.reshape(1,-1)
    cos_sim = cosine_similarity(ohe_df, y)
    cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
    results = list(cos_sim.index)
    results_df = subset_saa_new.loc[results]
    results_dict[i] = results_df

# %%
target[4]

# %%
subset_saa_new

# %%
mailchimp_poke2

# %%
name_first = input('First Name: ')

results_dict[mailchimp_poke2[mailchimp_poke2['First Name']
                             == name_first].index[0]].head(5)

# %% [markdown]
# These are the 5 most likely matches.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Next step would be to take a proactive approach to mitigate the number of emails that bounce in the future. We would suggest using the salesforce dataset to check for recent grads to reach out before they lose their student emails and ask for updated contact information and their subsequent plans after graduation. It would be easier to update records proactively when we still have accurate contact information. For subsequent plans after graduation, this would be to keeping location information of members to more accurately send regional events and functions.
