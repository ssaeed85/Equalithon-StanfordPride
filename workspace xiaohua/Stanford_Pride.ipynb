# %%
import pandas as pd
import numpy as np
import random

# %%
np.random.seed(42)

# %%
pd.set_option('display.max_columns', None)

# %%
stanford = pd.read_excel('../SAA Pride member reports headings.xlsx')

# %% [markdown]
# Create fake data.

# %%
common_first_name = ['Liam',
    'Noah',
    'Oliver',
    'James',
    'William',
    'Benjamin',
    'Henry',
    'Jack',
    'Alex',
    'Jackson',
    'Mateo',
    'Daniel',
    'Michael',
    'Mason',
    'Sebastian',
    'Ethan',
    'Mary',
    'Jennifer',
    'Linda',
    'Elizabeth',
    'Susan',
    'Jessica',
    'Sarah',
    'Karen',
    'Lisa',
    'Nancy',
    'Betty',
    'Margaret',
    'Sandra',
    'Ashley',
    'Kimberly',
    'Emily',
    'Michelle',
    'Taylor']

common_last_name = [
    'Smith',
    'Johnson',
    'Williams',
    'Brown',
    'Jones',
    'Miller',
    'Davis',
    'Garcia',
    'Rodriguez',
    'Wilson',
    'Lee',
    'Jackson',
    'Martin'
]

titles = ['Dr.', 'Mr.', 'Ms.', 'Mrs.']

# %%
city = ['Chicago', 'Boston', 'New York', 'San Francisco', 'Los Angeles', 'Austin','Dallas', 'Denver', 'Madrid', 'Tokyo', 'Seoul', 'London',
       'Beijing']

# %%
email_endings = ['@gmail.com', '@stanford.edu', '@alumni.stanford.edu']

# %%
pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))
# Out:
#      A   B   C   D
# 0   51  92  14  71
# 1   60  20  82  86
# 2   74  74  87  99
# 3   23   2  21  52
# 4    1  87  29  37
# ..  ..  ..  ..  ..
# 95  59  96  62  84
# 96  31  86  32  66
# 97  17  24  94  53
# 98  57  66  45  23
# 99  31  46  85  22
#
# [100 rows x 4 columns]

# %%
firsttname = []

while len(firsttname) < 300:
    firsttname.append(random.choice(common_first_name))

# %%
len(firsttname)
# Out:
# 300

# %%
lastname = []

while len(lastname) < 300:
        lastname.append(random.choice(common_last_name))

# %%
len(lastname)
# Out:
# 300

# %%
cityname = []

while len(cityname) < 300:
        cityname.append(random.choice(['*', None,city]))

# %%
len(cityname)
# Out:
# 300

# %%
classyear = []

while len(classyear) < 300:
        classyear.append(random.randint(1800, 2100))

# %%
len(classyear)
# Out:
# 300

# %%
email = []

while len(email) < 300:
        email.append(random.choice(email_endings))

# %%
len(email)
# Out:
# 300

# %%
stanford.saa_email_address = email
stanford.first_name = firsttname
stanford.last_name = lastname
stanford.pref_class_year = classyear
stanford.home_city = cityname

# %%
stanford.first_name
# Out:
# 0          James
# 1           Noah
# 2        Michael
# 3       Margaret
# 4          Mateo
#          ...
# 295        Susan
# 296    Elizabeth
# 297         Lisa
# 298    Sebastian
# 299      William
# Name: first_name, Length: 300, dtype: object

# %%
stanford
# Out:
#                pref_mail_name  pref_class_year  \
# 0            Mrs. James Smith             1966
# 1           Mrs. Noah Jackson             2050
# 2          Mrs. Michael Brown             1808
# 3         Mrs. Margaret Smith             1976
# 4            Mrs. Mateo Davis             1837
# ..                        ...              ...
# 295          Mrs. Susan Brown             2002
# 296        Mrs. Elizabeth Lee             1986
# 297           Mrs. Lisa Smith             1931
# 298  Mrs. Sebastian Rodriguez             1954
# 299          Mrs. William Lee             1872
#
#                                              home_city home_state_code  \
# 0                                                    *              MA
# 1    [Chicago, Boston, New York, San Francisco, Los...               *
# 2                                                    *              CO
# 3                                                    *              CA
# ...

# %%
country = {
           'Madrid' : 'Spain',
           'Tokyo' : 'Japan',
           'Seoul' : 'South Korea', 
           'London' : 'England',
       'Beijing' : 'China'}

# %%
stanford.home_country = stanford['home_city'].map(country)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-90a81663a308> in <module>
# ----> 1 stanford.home_country = stanford['home_city'].map(country)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1129             values = self._values
#    1130
# -> 1131             indexer = mapper.index.get_indexer(values)
#    1132             new_values = algorithms.take_1d(mapper._values, indexer)
#    1133
#
# ...

# %%
state = {'Chicago': 'IL', 
           'Boston': 'MA', 
           'New York' : 'NY', 
           'San Francisco': 'CA', 
           'Los Angeles' : 'CA', 
           'Austin' : 'TX',
        'Dallas': 'TX',
        'Denver': 'CO'}

# %%
stanford.home_state_code = stanford['home_city'].map(state)

# %%
stanford.fillna('*', inplace = True)

# %%
stanford

# %%
stanford.pref_mail_name = random.choice(titles) + " " + stanford.first_name + " " + stanford.last_name

# %%
stanford
# Out:
#                pref_mail_name  pref_class_year      home_city home_state_code  \
# 0            Mrs. James Smith             1834         Boston              MA
# 1           Mrs. Noah Jackson             1911        Beijing               *
# 2          Mrs. Michael Brown             1976         Denver              CO
# 3         Mrs. Margaret Smith             1853    Los Angeles              CA
# 4            Mrs. Mateo Davis             1827  San Francisco              CA
# ..                        ...              ...            ...             ...
# 295          Mrs. Susan Brown             2065         Dallas              TX
# 296        Mrs. Elizabeth Lee             1890         Madrid               *
# 297           Mrs. Lisa Smith             1950       New York              NY
# 298  Mrs. Sebastian Rodriguez             2044         Denver              CO
# 299          Mrs. William Lee             1897        Chicago              IL
#
# ...

# %%
num_ofDesiredRecords = 300

# %%
def createRandomPhoneNumber_SAA():
    range_start = 10**9
    range_end = 10**10 -1
    num = str(random.randint(range_start,range_end))
    num_str = "{0} {1}-{2}".format(num[:3], num[3:7],num[7:])
    return num_str

# %%
__  = []
for _ in range(0,num_ofDesiredRecords):
    __.append(random.choice(['*',None,createRandomPhoneNumber_SAA()]))
    
stanford.home_phone_number = __

# %%
stanford
# Out:
#                pref_mail_name  pref_class_year      home_city home_state_code  \
# 0            Mrs. James Smith             1834         Boston              MA
# 1           Mrs. Noah Jackson             1911        Beijing               *
# 2          Mrs. Michael Brown             1976         Denver              CO
# 3         Mrs. Margaret Smith             1853    Los Angeles              CA
# 4            Mrs. Mateo Davis             1827  San Francisco              CA
# ..                        ...              ...            ...             ...
# 295          Mrs. Susan Brown             2065         Dallas              TX
# 296        Mrs. Elizabeth Lee             1890         Madrid               *
# 297           Mrs. Lisa Smith             1950       New York              NY
# 298  Mrs. Sebastian Rodriguez             2044         Denver              CO
# 299          Mrs. William Lee             1897        Chicago              IL
#
# ...
