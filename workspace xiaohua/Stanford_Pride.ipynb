# %%
import pandas as pd
import numpy as np
import random

# %%
pd.set_option('display.max_columns', None)

# %%
stanford = pd.read_excel('../SAA Pride member reports headings.xlsx')

# %% [markdown]
# Create fake data.

# %%
common_first_name = ['Liam',
    'Noah',
    'Oliver',
    'James',
    'William',
    'Benjamin',
    'Henry',
    'Jack',
    'Alex',
    'Jackson',
    'Mateo',
    'Daniel',
    'Michael',
    'Mason',
    'Sebastian',
    'Ethan',
    'Mary',
    'Jennifer',
    'Linda',
    'Elizabeth',
    'Susan',
    'Jessica',
    'Sarah',
    'Karen',
    'Lisa',
    'Nancy',
    'Betty',
    'Margaret',
    'Sandra',
    'Ashley',
    'Kimberly',
    'Emily',
    'Michelle',
    'Taylor']

common_last_name = [
    'Smith',
    'Johnson',
    'Williams',
    'Brown',
    'Jones',
    'Miller',
    'Davis',
    'Garcia',
    'Rodriguez',
    'Wilson',
    'Lee',
    'Jackson',
    'Martin'
]

titles = ['Dr.', 'Mr.', 'Ms.', 'Mrs.']

# %%
city = ['Chicago', 'Boston', 'New York', 'San Francisco', 'Los Angeles', 'Austin', 'Madrid', 'Tokyo', 'Seoul', 'London',
       'Beijing']

# %%
email_endings = ['@gmail.com', '@stanford.edu', '@alumni.stanford.edu']

# %%
pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))
# Out:
#      A   B   C   D
# 0   68  44  61   8
# 1   82   3  98  49
# 2   20  69  87  30
# 3   12   3  37  28
# 4   43  90  93  93
# ..  ..  ..  ..  ..
# 95  52  17  98  63
# 96  79  42  95  61
# 97  88  56  45  36
# 98  64  23   1  60
# 99  31  10  40  96
#
# [100 rows x 4 columns]

# %%
firsttname = []

while len(firsttname) < 300:
    firsttname.append(random.choice(common_first_name))

# %%
len(firsttname)
# Out:
# 300

# %%
lastname = []

while len(lastname) < 300:
        lastname.append(random.choice(common_last_name))

# %%
len(lastname)
# Out:
# 300

# %%
cityname = []

while len(cityname) < 300:
        cityname.append(f''+random.choice(email_endings))

# %%
len(cityname)
# Out:
# 300

# %%
classyear = []

while len(classyear) < 300:
        classyear.append(random.randint(1000, 3000))

# %%
len(classyear)
# Out:
# 300

# %%
email = []

while len(email) < 300:
        email.append(random.choice(email_endings))

# %%
len(email)
# Out:
# 300

# %%
stanford.saa_email_address = email

# %%
stanford.first_name = firsttname
stanford.last_name = lastname
stanford.pref_class_year = classyear
stanford.home_city = cityname

# %%
stanford.first_name
# Out:
# 0          Nancy
# 1       Michelle
# 2          Mateo
# 3           Jack
# 4       Margaret
#          ...
# 295        Sarah
# 296    Elizabeth
# 297         Mary
# 298       Ashley
# 299       Taylor
# Name: first_name, Length: 300, dtype: object

# %%
stanford
# Out:
#     pref_mail_name  pref_class_year      home_city home_state_code  \
# 0              NaN             2222          Tokyo             NaN
# 1              NaN             2241        Beijing             NaN
# 2              NaN             1602          Tokyo             NaN
# 3              NaN             2773        Beijing             NaN
# 4              NaN             1627         London             NaN
# ..             ...              ...            ...             ...
# 295            NaN             2648  San Francisco             NaN
# 296            NaN             2062         London             NaN
# 297            NaN             1341          Tokyo             NaN
# 298            NaN             2762        Beijing             NaN
# 299            NaN             2758         Austin             NaN
#
#     home_country home_phone_area_code home_phone_number home_email_address  \
# 0            NaN                  NaN               NaN                NaN
# 1            NaN                  NaN               NaN                NaN
# 2            NaN                  NaN               NaN                NaN
# 3            NaN                  NaN               NaN                NaN
# 4            NaN                  NaN               NaN                NaN
# ..           ...                  ...               ...                ...
# 295          NaN                  NaN               NaN                NaN
# 296          NaN                  NaN               NaN                NaN
# 297          NaN                  NaN               NaN                NaN
# 298          NaN                  NaN               NaN                NaN
# 299          NaN                  NaN               NaN                NaN
#
#     bus_city bus_state_code bus_country bus_phone_area_code bus_phone_number  \
# 0        NaN            NaN         NaN                 NaN              NaN
# 1        NaN            NaN         NaN                 NaN              NaN
# 2        NaN            NaN         NaN                 NaN              NaN
# 3        NaN            NaN         NaN                 NaN              NaN
# 4        NaN            NaN         NaN                 NaN              NaN
# ..       ...            ...         ...                 ...              ...
# 295      NaN            NaN         NaN                 NaN              NaN
# 296      NaN            NaN         NaN                 NaN              NaN
# 297      NaN            NaN         NaN                 NaN              NaN
# 298      NaN            NaN         NaN                 NaN              NaN
# 299      NaN            NaN         NaN                 NaN              NaN
#
#     bus_email_address first_name last_name pref_name_sort email_switch  \
# 0                 NaN      Nancy   Jackson            NaN          NaN
# 1                 NaN   Michelle     Smith            NaN          NaN
# 2                 NaN      Mateo    Miller            NaN          NaN
# 3                 NaN       Jack     Brown            NaN          NaN
# 4                 NaN   Margaret  Williams            NaN          NaN
# ..                ...        ...       ...            ...          ...
# 295               NaN      Sarah   Johnson            NaN          NaN
# 296               NaN  Elizabeth     Jones            NaN          NaN
# 297               NaN       Mary    Martin            NaN          NaN
# 298               NaN     Ashley    Miller            NaN          NaN
# 299               NaN     Taylor    Garcia            NaN          NaN
#
#         saa_email_address gsb_email_address other_email_address  \
# 0    @alumni.stanford.edu               NaN                 NaN
# 1    @alumni.stanford.edu               NaN                 NaN
# 2    @alumni.stanford.edu               NaN                 NaN
# 3           @stanford.edu               NaN                 NaN
# 4    @alumni.stanford.edu               NaN                 NaN
# ..                    ...               ...                 ...
# 295            @gmail.com               NaN                 NaN
# 296         @stanford.edu               NaN                 NaN
# 297            @gmail.com               NaN                 NaN
# 298            @gmail.com               NaN                 NaN
# 299  @alumni.stanford.edu               NaN                 NaN
#
#     pref_phone_area_code pref_phone_number pref_phone_addr_type  \
# 0                    NaN               NaN                  NaN
# 1                    NaN               NaN                  NaN
# 2                    NaN               NaN                  NaN
# 3                    NaN               NaN                  NaN
# 4                    NaN               NaN                  NaN
# ..                   ...               ...                  ...
# 295                  NaN               NaN                  NaN
# 296                  NaN               NaN                  NaN
# 297                  NaN               NaN                  NaN
# 298                  NaN               NaN                  NaN
# 299                  NaN               NaN                  NaN
#
#     memb_status_desc short_degree_string parent_degree_string  \
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN
# ..               ...                 ...                  ...
# 295              NaN                 NaN                  NaN
# 296              NaN                 NaN                  NaN
# 297              NaN                 NaN                  NaN
# 298              NaN                 NaN                  NaN
# 299              NaN                 NaN                  NaN
#
#     short_degree_string_spouse parent_degree_string_spouse primary_sort_name  \
# 0                          NaN                         NaN               NaN
# 1                          NaN                         NaN               NaN
# 2                          NaN                         NaN               NaN
# 3                          NaN                         NaN               NaN
# 4                          NaN                         NaN               NaN
# ..                         ...                         ...               ...
# 295                        NaN                         NaN               NaN
# 296                        NaN                         NaN               NaN
# 297                        NaN                         NaN               NaN
# 298                        NaN                         NaN               NaN
# 299                        NaN                         NaN               NaN
#
#     plan_name primary_ind
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
# ..        ...         ...
# 295       NaN         NaN
# 296       NaN         NaN
# 297       NaN         NaN
# 298       NaN         NaN
# 299       NaN         NaN
#
# [300 rows x 32 columns]
