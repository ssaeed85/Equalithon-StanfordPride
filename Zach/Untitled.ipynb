# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
mailchimp_data = pd.read_csv('./MailChimp_cleaned_records_headers.csv')
pd.set_option('max_columns', None)
mailchimp_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS]
# Index: []

# %%
# mailchimp_data.drop(['Board Member', 'Gender', 'Reunion Year',\
#                      'Country', 'Degree', 'MEMBER_RATING',\
#                      'OPTIN_TIME', 'OPTIN_IP', 'CONFIRM_TIME',\
#                      'CONFIRM_IP', 'LATITUDE','LONGITUDE', 'GMTOFF',\
#                      'DSTOFF', 'TIMEZONE', 'CC', 'REGION', 'LEID',\
#                      'EUID', 'NOTES', 'TAGS'], axis =1, inplace=True)
# mailchimp_data

# %% [markdown]
# The mailchimp dataset comes from the salesforce dataset. This Cleaned dataset would only include emails that have bounced for one reason or another. It will not include any members who have opted out of the email service or those that are receiving emails without any complications. It is important to note that updating information within salesforce for those who have opted out may re-instantiate the email services so we are specifically working with cleaned/bounced records. Additionally, the datasets created for those who are Subscribed and Unsubscribed will have different column names than the Cleaned dataset here (ie Clean_Time, Clean_campaign_title, ect). Therefore any function created here may not work for those datasets.

# %%
saa_pride_data = pd.read_excel('./SAA Pride member reports headings.xlsx')
saa_pride_data.reset_index(inplace = True)
saa_pride_data
# Out:
# Empty DataFrame
# Columns: [index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
# saa_pride_data.drop(['home_country', 'home_phone_area_code',\
#                      'home_phone_number', 'bus_city', 'bus_state_code',\
#                     'bus_country', 'bus_phone_area_code',\
#                      'bus_phone_number', 'bus_email_address',
#                     'pref_phone_area_code', 'pref_phone_addr_type',
#                     'memb_status_desc', 'parent_degree_string', \
#                     'short_degree_string_spouse', 
#                      'parent_degree_string_spouse', 'primary_sort_name',\
#                     'plan_name', 'primary_ind'], axis =1, inplace=True)
# saa_pride_data

# %% [markdown]
# The Stanford Alumni Association has it's own dataset that may or may not have additional or more recent data on some of the members. It may also have outdated data. Students are given an email but when they become alumni the email needs to be updated. Whether it is updated to specifically an 'alumni.stanford.edu' address or to another would be at the students discrepancy and isn't always updated.

# %%
combined_data = mailchimp_data.merge(saa_pride_data,\
                                     left_on =['First Name', 'Last Name'],\
                                     right_on=['first_name', 'last_name'],\
                                     how='outer')
combined_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS, index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
saa_pride_data
# Out:
# Empty DataFrame
# Columns: [index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
saa_mock = pd.read_excel('../data/SAA_FakeDB.xlsx')
saa_mock
# Out:
#     pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 0              NaN              NaN    London             NaN          NaN
# 1              NaN              NaN    Madrid             NaN        Japan
# 2              NaN              NaN  Shanghai             NaN          USA
# 3              NaN              NaN   Chicago              IL          UAE
# 4              NaN           1994.0     Seoul             NaN            *
# ..             ...              ...       ...             ...          ...
# 95             NaN              NaN   Beijing             NaN          UAE
# 96             NaN              NaN     Seoul             NaN          UAE
# 97             NaN              NaN   Beijing             NaN          UAE
# 98             NaN           2011.0       NaN             NaN            *
# 99             NaN              NaN  Shanghai             NaN            *
#
#     home_phone_area_code home_phone_number                home_email_address  \
# 0                    NaN               NaN                                 *
# 1                    NaN               NaN                                 *
# 2                    NaN      898 7073-217                               NaN
# 3                    NaN               NaN                               NaN
# 4                    NaN               NaN                               NaN
# ..                   ...               ...                               ...
# 95                   NaN               NaN                               NaN
# 96                   NaN               NaN                                 *
# 97                   NaN               NaN  elizabeth.martinez6250@gmail.com
# 98                   NaN               NaN     sbrown7443@stanfordalumni.org
# 99                   NaN                 *                               NaN
#
#     bus_city  bus_state_code bus_country  bus_phone_area_code  \
# 0        NaN             NaN      Kuwait                  NaN
# 1        NaN             NaN         NaN                  NaN
# 2        NaN             NaN         UAE                  NaN
# 3        NaN             NaN       China                  NaN
# 4        NaN             NaN         NaN                  NaN
# ..       ...             ...         ...                  ...
# 95       NaN             NaN         USA                  NaN
# 96       NaN             NaN      Kuwait                  NaN
# 97       NaN             NaN       Japan                  NaN
# 98       NaN             NaN       Japan                  NaN
# 99       NaN             NaN         NaN                  NaN
#
#     bus_phone_number bus_email_address first_name  last_name  pref_name_sort  \
# 0                NaN               NaN      Linda      Brown             NaN
# 1                NaN               NaN       Mary  Rodriguez             NaN
# 2                NaN               NaN      Sarah  Rodriguez             NaN
# 3                NaN               NaN    Jessica      Jones             NaN
# 4                NaN               NaN    Jessica   Martinez             NaN
# ..               ...               ...        ...        ...             ...
# 95               NaN               NaN     Oliver  Rodriguez             NaN
# 96               NaN               NaN      James      Brown             NaN
# 97               NaN               NaN  Elizabeth   Martinez             NaN
# 98               NaN               NaN      Sarah      Brown             NaN
# 99               NaN               NaN  Elizabeth      Smith             NaN
#
#     email_switch                        saa_email_address gsb_email_address  \
# 0            NaN           lindab1567@alumni.stanford.edu               NaN
# 1            NaN                                        *               NaN
# 2            NaN   sarah.rodriguez992@alumni.stanford.edu               NaN
# 3            NaN         jessicaj5803@alumni.stanford.edu               NaN
# 4            NaN  jessicamartinez1707@alumni.stanford.edu               NaN
# ..           ...                                      ...               ...
# 95           NaN                                        *               NaN
# 96           NaN                                        *               NaN
# 97           NaN                                      NaN               NaN
# 98           NaN           sarahb7790@alumni.stanford.edu               NaN
# 99           NaN                                      NaN               NaN
#
#     other_email_address  pref_phone_area_code  pref_phone_number  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   NaN                   NaN                NaN
# 3                   NaN                   NaN                NaN
# 4                   NaN                   NaN                NaN
# ..                  ...                   ...                ...
# 95                  NaN                   NaN                NaN
# 96                  NaN                   NaN                NaN
# 97                  NaN                   NaN                NaN
# 98                  NaN                   NaN                NaN
# 99                  NaN                   NaN                NaN
#
#     pref_phone_addr_type  memb_status_desc     short_degree_string  \
# 0                    NaN               NaN         PhD '94, BA '82
# 1                    NaN               NaN          MA '85, BS '92
# 2                    NaN               NaN  BS '88, BS '95, MA '85
# 3                    NaN               NaN                 MBA '81
# 4                    NaN               NaN                     NaN
# ..                   ...               ...                     ...
# 95                   NaN               NaN                     NaN
# 96                   NaN               NaN          BS '94, MS '92
# 97                   NaN               NaN       '85, MBA '87, '92
# 98                   NaN               NaN         PhD '84, MS '91
# 99                   NaN               NaN                  MS '83
#
#     parent_degree_string  short_degree_string_spouse  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
# ..                   ...                         ...
# 95                   NaN                         NaN
# 96                   NaN                         NaN
# 97                   NaN                         NaN
# 98                   NaN                         NaN
# 99                   NaN                         NaN
#
#     parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind   0
# 0                           NaN                NaN        NaN          NaN NaN
# 1                           NaN                NaN        NaN          NaN NaN
# 2                           NaN                NaN        NaN          NaN NaN
# 3                           NaN                NaN        NaN          NaN NaN
# 4                           NaN                NaN        NaN          NaN NaN
# ..                          ...                ...        ...          ...  ..
# 95                          NaN                NaN        NaN          NaN NaN
# 96                          NaN                NaN        NaN          NaN NaN
# 97                          NaN                NaN        NaN          NaN NaN
# 98                          NaN                NaN        NaN          NaN NaN
# 99                          NaN                NaN        NaN          NaN NaN
#
# [100 rows x 33 columns]

# %% [markdown]
# A random mock dataset was produced from the format of the SAA database for a proof of concept.

# %%
# Filter necessary columns
saa_mock2 = saa_mock.filter(['home_country', 'home_email_address',\
                 'bus_email_address', 'first_name', 'last_name', 'email_switch',\
                'saa_email_address', 'gsb_email_address', 'other_email_address',])
saa_mock2
# Out:
#    home_country                home_email_address bus_email_address  \
# 0           NaN                                 *               NaN
# 1         Japan                                 *               NaN
# 2           USA                               NaN               NaN
# 3           UAE                               NaN               NaN
# 4             *                               NaN               NaN
# ..          ...                               ...               ...
# 95          UAE                               NaN               NaN
# 96          UAE                                 *               NaN
# 97          UAE  elizabeth.martinez6250@gmail.com               NaN
# 98            *     sbrown7443@stanfordalumni.org               NaN
# 99            *                               NaN               NaN
#
#    first_name  last_name  email_switch  \
# 0       Linda      Brown           NaN
# 1        Mary  Rodriguez           NaN
# 2       Sarah  Rodriguez           NaN
# 3     Jessica      Jones           NaN
# 4     Jessica   Martinez           NaN
# ..        ...        ...           ...
# 95     Oliver  Rodriguez           NaN
# 96      James      Brown           NaN
# 97  Elizabeth   Martinez           NaN
# 98      Sarah      Brown           NaN
# 99  Elizabeth      Smith           NaN
#
#                           saa_email_address gsb_email_address  \
# 0            lindab1567@alumni.stanford.edu               NaN
# 1                                         *               NaN
# 2    sarah.rodriguez992@alumni.stanford.edu               NaN
# 3          jessicaj5803@alumni.stanford.edu               NaN
# 4   jessicamartinez1707@alumni.stanford.edu               NaN
# ..                                      ...               ...
# 95                                        *               NaN
# 96                                        *               NaN
# 97                                      NaN               NaN
# 98           sarahb7790@alumni.stanford.edu               NaN
# 99                                      NaN               NaN
#
#     other_email_address
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 95                  NaN
# 96                  NaN
# 97                  NaN
# 98                  NaN
# 99                  NaN
#
# [100 rows x 9 columns]

# %%
# Need to split short_degree_string for OneHotEncoding
# saa_mock2.short_degree_string[0]

# %%
# saa_mock2['short_degree_string'] = saa_mock2['short_degree_string'].str.split()

# %%
# unique_degree_list = []
# for degrees in saa_mock2['short_degree_string'].dropna().tolist():
#     for degree in degrees:
#         unique_degree_list.append(degree)
# unique_degree_list =list(set(unique_degree_list))
# unique_degree_list

# %%
mailchimp_mock = pd.read_csv('../data/Fake_MailChimp_cleaned.csv')
mailchimp_mock
# Out:
#                         Email Address First Name  Last Name  Board Member  \
# 0             brodriguez369@gmail.com    Barbara  Rodriguez          True
# 1    liamjones7027@stanfordalumni.org       Liam      Jones         False
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez          True
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia          True
# 4               m.davis4650@gmail.com       Mary    Johnson          True
#
#   Gender      Chapter  Reunion Year Country Degree  MEMBER_RATING  OPTIN_TIME  \
# 0    NaN  New England           NaN     USA    NaN            NaN         NaN
# 1      M     Bay Area           NaN     USA    NaN            NaN         NaN
# 2    NaN     Bay Area           NaN     USA  MD;MA            NaN         NaN
# 3      F  New England           NaN     USA     MS            NaN         NaN
# 4    NaN        Texas           NaN     USA    NaN            NaN         NaN
#
#    OPTIN_IP  CONFIRM_TIME  CONFIRM_IP  LATITUDE  LONGITUDE  GMTOFF  DSTOFF  \
# 0       NaN           NaN         NaN       NaN        NaN     NaN     NaN
# 1       NaN           NaN         NaN       NaN        NaN     NaN     NaN
# 2       NaN           NaN         NaN       NaN        NaN     NaN     NaN
# 3       NaN           NaN         NaN       NaN        NaN     NaN     NaN
# 4       NaN           NaN         NaN       NaN        NaN     NaN     NaN
#
#    TIMEZONE  CC  REGION  CLEAN_TIME  CLEAN_CAMPAIGN_TITLE  CLEAN_CAMPAIGN_ID  \
# 0       NaN NaN     NaN         NaN                   NaN                NaN
# 1       NaN NaN     NaN         NaN                   NaN                NaN
# 2       NaN NaN     NaN         NaN                   NaN                NaN
# 3       NaN NaN     NaN         NaN                   NaN                NaN
# 4       NaN NaN     NaN         NaN                   NaN                NaN
#
#    LEID  EUID  NOTES  TAGS
# 0   NaN   NaN    NaN   NaN
# 1   NaN   NaN    NaN   NaN
# 2   NaN   NaN    NaN   NaN
# 3   NaN   NaN    NaN   NaN
# 4   NaN   NaN    NaN   NaN

# %%
# Filter necessary columns
mailchimp_mock2 = mailchimp_mock.filter(['Email Address', 'First Name', 'Last Name',\
                    'Country'])
mailchimp_mock2
# Out:
#                         Email Address First Name  Last Name Country
# 0             brodriguez369@gmail.com    Barbara  Rodriguez     USA
# 1    liamjones7027@stanfordalumni.org       Liam      Jones     USA
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez     USA
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia     USA
# 4               m.davis4650@gmail.com       Mary    Johnson     USA

# %%
mailchimp_mock2['handle'] = mailchimp_mock2['Email Address'].str.split('@').str[0]
mailchimp_mock2
# Out:
#                         Email Address First Name  Last Name Country  \
# 0             brodriguez369@gmail.com    Barbara  Rodriguez     USA
# 1    liamjones7027@stanfordalumni.org       Liam      Jones     USA
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez     USA
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia     USA
# 4               m.davis4650@gmail.com       Mary    Johnson     USA
#
#             handle
# 0    brodriguez369
# 1    liamjones7027
# 2       lindam7966
# 3  liam.garcia7988
# 4      m.davis4650

# %% [markdown]
# ### Similarity Function Building (Cosine)

# %%
# # First we take a row we are trying to identify.
# target = mailchimp_mock2.iloc[0]
# target

# %%
# target_dict = {'first_name': target[1], 'last_name': target[2],\
#                'saa_email_address': target[0],
#                'home_email_address': target[0],
#                'bus_email_address': target[0],
#                'email_switch': target[0],
#                'gsb_email_address': target[0],
#                'other_email_address': target[0],
#                'home_country': target[3]}
# saa_mock2 = saa_mock2.append(target_dict, ignore_index = True)
# saa_mock2

# %%
# # We then subset the SAA data by the first name
# saa_mock2.fillna(value='Not Available', inplace=True)
# sub_saa = saa_mock2[saa_mock2['first_name'] == target[1]].astype(str)
# sub_saa

# %%
saa_mock2.fillna(value='Not Available', inplace=True)
emails = ['home_email_address', 'bus_email_address', 'email_switch', 'saa_email_address',\
         'gsb_email_address', 'other_email_address']
handles = []
for x in emails:
    for i in range(0,saa_mock2.shape[1]+1):
        if '@' in saa_mock2[x][i]:
            saa_mock2[x+'_handle'] = saa_mock2[x].str.split('@').str[0]
            handles.append(x+'_handle')
        else:
            pass

# %%
handles
# Out:
# ['home_email_address_handle',
#  'saa_email_address_handle',
#  'saa_email_address_handle',
#  'saa_email_address_handle',
#  'saa_email_address_handle',
#  'saa_email_address_handle']

# %%
saa_mock2
# Out:
#      home_country                home_email_address bus_email_address  \
# 0   Not Available                                 *     Not Available
# 1           Japan                                 *     Not Available
# 2             USA                     Not Available     Not Available
# 3             UAE                     Not Available     Not Available
# 4               *                     Not Available     Not Available
# ..            ...                               ...               ...
# 95            UAE                     Not Available     Not Available
# 96            UAE                                 *     Not Available
# 97            UAE  elizabeth.martinez6250@gmail.com     Not Available
# 98              *     sbrown7443@stanfordalumni.org     Not Available
# 99              *                     Not Available     Not Available
#
#    first_name  last_name   email_switch  \
# 0       Linda      Brown  Not Available
# 1        Mary  Rodriguez  Not Available
# 2       Sarah  Rodriguez  Not Available
# 3     Jessica      Jones  Not Available
# 4     Jessica   Martinez  Not Available
# ..        ...        ...            ...
# 95     Oliver  Rodriguez  Not Available
# 96      James      Brown  Not Available
# 97  Elizabeth   Martinez  Not Available
# 98      Sarah      Brown  Not Available
# 99  Elizabeth      Smith  Not Available
#
#                           saa_email_address gsb_email_address  \
# 0            lindab1567@alumni.stanford.edu     Not Available
# 1                                         *     Not Available
# 2    sarah.rodriguez992@alumni.stanford.edu     Not Available
# 3          jessicaj5803@alumni.stanford.edu     Not Available
# 4   jessicamartinez1707@alumni.stanford.edu     Not Available
# ..                                      ...               ...
# 95                                        *     Not Available
# 96                                        *     Not Available
# 97                            Not Available     Not Available
# 98           sarahb7790@alumni.stanford.edu     Not Available
# 99                            Not Available     Not Available
#
#    other_email_address home_email_address_handle saa_email_address_handle
# 0        Not Available                         *               lindab1567
# 1        Not Available                         *                        *
# 2        Not Available             Not Available       sarah.rodriguez992
# 3        Not Available             Not Available             jessicaj5803
# 4        Not Available             Not Available      jessicamartinez1707
# ..                 ...                       ...                      ...
# 95       Not Available             Not Available                        *
# 96       Not Available                         *                        *
# 97       Not Available    elizabeth.martinez6250            Not Available
# 98       Not Available                sbrown7443               sarahb7790
# 99       Not Available             Not Available            Not Available
#
# [100 rows x 11 columns]

# %%
emails, handles
# Out:
# (['home_email_address',
#   'bus_email_address',
#   'email_switch',
#   'saa_email_address',
#   'gsb_email_address',
#   'other_email_address'],
#  ['home_email_address_handle',
#   'saa_email_address_handle',
#   'saa_email_address_handle',
#   'saa_email_address_handle',
#   'saa_email_address_handle',
#   'saa_email_address_handle'])

# %%
for i in range(0,mailchimp_mock2.shape[1]):
    target = mailchimp_mock2.iloc[i]
target
# Out:
# Email Address    m.davis4650@gmail.com
# First Name                        Mary
# Last Name                      Johnson
# Country                            USA
# handle                     m.davis4650
# Name: 4, dtype: object

# %%
def ohe(df, column):    
    for col in column:
        train = df[[col]]
        ohe = OneHotEncoder(sparse=False, handle_unknown="error")
        ohe.fit(train)
        encoded_train = ohe.transform(train)
        col_names = [f"{col}_{f}" for f in ohe.get_feature_names()]
        encoded_train = pd.DataFrame(encoded_train,
                                     columns=col_names, index=df.index)
        df = pd.concat([df, encoded_train], axis=1)
        
    return df

# %%
results_dict = {}
for i in range(0,mailchimp_mock2.shape[1]):
    target = mailchimp_mock2.iloc[i]
    target_dict = {'first_name': [target[1]], 'last_name': [target[2]],\
               emails[0]: [target[0]],
               emails[1]: [target[0]],
               emails[2]: [target[0]],
               emails[3]: [target[0]],
               emails[4]: [target[0]],
               emails[5]: [target[0]],
                   handles[0]: [target[4]],
                   handles[1]: [target[4]],
                   handles[2]: [target[4]],
                   handles[3]: [target[4]],
                   handles[4]: [target[4]],
                   handles[5]: [target[4]],
               'home_country': [target[3]]}
    df = pd.DataFrame.from_dict(target_dict)
    subset_saa = saa_mock2[saa_mock2['first_name'] == df.loc[0,'first_name']] 
    #the 0 is calling for row, so it does not return a series
    subset_saa_new = pd.concat([df,subset_saa], axis = 0)
    ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
    ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
    y = np.array(ohe_df.iloc[0])
    y = y.reshape(1,-1)
    cos_sim = cosine_similarity(ohe_df, y)
    cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
    results = list(cos_sim.index)
    results_df = subset_saa_new.loc[results]
    results_dict[i] = results_df

# %%
mailchimp_mock2
# Out:
#                         Email Address First Name  Last Name Country  \
# 0             brodriguez369@gmail.com    Barbara  Rodriguez     USA
# 1    liamjones7027@stanfordalumni.org       Liam      Jones     USA
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez     USA
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia     USA
# 4               m.davis4650@gmail.com       Mary    Johnson     USA
#
#             handle
# 0    brodriguez369
# 1    liamjones7027
# 2       lindam7966
# 3  liam.garcia7988
# 4      m.davis4650

# %%
results_dict[3]
# Out:
#    first_name  last_name                     home_email_address  \
# 0        Liam     Garcia     liam.garcia7988@stanfordalumni.org
# 92       Liam     Garcia      liamgarcia268@alumni.stanford.edu
# 30       Liam  Rodriguez                          Not Available
# 34       Liam      Jones        l.jones1950@alumni.stanford.edu
# 82       Liam      Jones                                      *
# 86       Liam  Rodriguez  liam.rodriguez6028@stanfordalumni.org
#
#                        bus_email_address                        email_switch  \
# 0     liam.garcia7988@stanfordalumni.org  liam.garcia7988@stanfordalumni.org
# 92                         Not Available                       Not Available
# 30  liamrodriguez3500@stanfordalumni.org                       Not Available
# 34                         Not Available                       Not Available
# 82                         Not Available                       Not Available
# 86                         Not Available                       Not Available
#
#                         saa_email_address                   gsb_email_address  \
# 0      liam.garcia7988@stanfordalumni.org  liam.garcia7988@stanfordalumni.org
# 92     liam.garcia848@alumni.stanford.edu                       Not Available
# 30  liam.rodriguez8596@stanfordalumni.org                       Not Available
# 34                          Not Available                       Not Available
# 82            liamj506@stanfordalumni.org                       Not Available
# 86                                      *                       Not Available
#
#                    other_email_address home_email_address_handle  \
# 0   liam.garcia7988@stanfordalumni.org           liam.garcia7988
# 92                       Not Available             liamgarcia268
# 30                       Not Available             Not Available
# 34                       Not Available               l.jones1950
# 82                       Not Available                         *
# 86                       Not Available        liam.rodriguez6028
#
#    saa_email_address_handle   home_country
# 0           liam.garcia7988            USA
# 92           liam.garcia848            USA
# 30       liam.rodriguez8596          China
# 34            Not Available  Not Available
# 82                 liamj506          China
# 86                        *              *

# %% [markdown]
# Put into a loop.

# %%
for x in range(len(mailchimp_mock2)):
    target = mailchimp_mock2.iloc[x]
    print(target[1])
# Out:
# Barbara
# Liam
# Liam
# Liam
# Mary

# %%
mailchimp_mock2
# Out:
#                         Email Address First Name  Last Name Country  \
# 0             brodriguez369@gmail.com    Barbara  Rodriguez     USA
# 1    liamjones7027@stanfordalumni.org       Liam      Jones     USA
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez     USA
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia     USA
# 4               m.davis4650@gmail.com       Mary    Johnson     USA
#
#             handle
# 0    brodriguez369
# 1    liamjones7027
# 2       lindam7966
# 3  liam.garcia7988
# 4      m.davis4650

# %%
saa_mock2
# Out:
#      home_country                home_email_address bus_email_address  \
# 0   Not Available                                 *     Not Available
# 1           Japan                                 *     Not Available
# 2             USA                     Not Available     Not Available
# 3             UAE                     Not Available     Not Available
# 4               *                     Not Available     Not Available
# ..            ...                               ...               ...
# 95            UAE                     Not Available     Not Available
# 96            UAE                                 *     Not Available
# 97            UAE  elizabeth.martinez6250@gmail.com     Not Available
# 98              *     sbrown7443@stanfordalumni.org     Not Available
# 99              *                     Not Available     Not Available
#
#    first_name  last_name   email_switch  \
# 0       Linda      Brown  Not Available
# 1        Mary  Rodriguez  Not Available
# 2       Sarah  Rodriguez  Not Available
# 3     Jessica      Jones  Not Available
# 4     Jessica   Martinez  Not Available
# ..        ...        ...            ...
# 95     Oliver  Rodriguez  Not Available
# 96      James      Brown  Not Available
# 97  Elizabeth   Martinez  Not Available
# 98      Sarah      Brown  Not Available
# 99  Elizabeth      Smith  Not Available
#
#                           saa_email_address gsb_email_address  \
# 0            lindab1567@alumni.stanford.edu     Not Available
# 1                                         *     Not Available
# 2    sarah.rodriguez992@alumni.stanford.edu     Not Available
# 3          jessicaj5803@alumni.stanford.edu     Not Available
# 4   jessicamartinez1707@alumni.stanford.edu     Not Available
# ..                                      ...               ...
# 95                                        *     Not Available
# 96                                        *     Not Available
# 97                            Not Available     Not Available
# 98           sarahb7790@alumni.stanford.edu     Not Available
# 99                            Not Available     Not Available
#
#    other_email_address home_email_address_handle saa_email_address_handle
# 0        Not Available                         *               lindab1567
# 1        Not Available                         *                        *
# 2        Not Available             Not Available       sarah.rodriguez992
# 3        Not Available             Not Available             jessicaj5803
# 4        Not Available             Not Available      jessicamartinez1707
# ..                 ...                       ...                      ...
# 95       Not Available             Not Available                        *
# 96       Not Available                         *                        *
# 97       Not Available    elizabeth.martinez6250            Not Available
# 98       Not Available                sbrown7443               sarahb7790
# 99       Not Available             Not Available            Not Available
#
# [100 rows x 11 columns]

# %%
for i in range(0,mailchimp_mock2.shape[1]):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# results_dict = {}
# for i in range(0,mailchimp_mock2.shape[1]+1):
#     target = mailchimp_mock2.iloc[i]
#     target_dict = {'first_name': [target[1]], 'last_name': [target[2]],\
#                'saa_email_address': [target[0]],
#                'home_email_address': [target[0]],
#                'bus_email_address': [target[0]],
#                'email_switch': [target[0]],
#                'gsb_email_address': [target[0]],
#                'other_email_address': [target[0]],
#                'home_country': [target[3]]}
#     df = pd.DataFrame.from_dict(target_dict)
#     subset_saa = saa_mock2[saa_mock2['first_name'] == df.loc[0,'first_name']] 
#     #the 0 is calling for row, so it does not return a series
#     subset_saa_new = pd.concat([df,subset_saa], axis = 0)
#     ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
#     ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
#     y = np.array(ohe_df.iloc[0])
#     y = y.reshape(1,-1)
#     cos_sim = cosine_similarity(ohe_df, y)
#     cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
#     results = list(cos_sim.index)
#     results_df = subset_saa_new.loc[results]
#     results_dict[i] = results_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-27942a41578d> in <module>
#      14     #the 0 is calling for row, so it does not return a series
#      15     subset_saa_new = pd.concat([df,subset_saa], axis = 0)
# ---> 16     ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
#      17     ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
#      18     y = np.array(ohe_df.iloc[0])
#
# <ipython-input-24-f8299269d73d> in ohe(df, column)
#       3         train = df[[col]]
#       4         ohe = OneHotEncoder(sparse=False, handle_unknown="error")
# ----> 5         ohe.fit(train)
#       6         encoded_train = ohe.transform(train)
#       7         col_names = [f"{col}_{f}" for f in ohe.get_feature_names()]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     383         """
#     384         self._validate_keywords()
# --> 385         self._fit(X, handle_unknown=self.handle_unknown)
#     386         self.drop_idx_ = self._compute_drop_idx()
#     387         return self
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown)
#      72
#      73     def _fit(self, X, handle_unknown='error'):
# ---> 74         X_list, n_samples, n_features = self._check_X(X)
#      75
#      76         if self.categories != 'auto':
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py in _check_X(self, X)
#      58         for i in range(n_features):
#      59             Xi = self._get_feature(X, feature_idx=i)
# ---> 60             Xi = check_array(Xi, ensure_2d=False, dtype=None,
#      61                              force_all_finite=needs_validation)
#      62             X_columns.append(Xi)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     102     elif X.dtype == np.dtype('object') and not allow_nan:
#     103         if _object_dtype_isnan(X).any():
# --> 104             raise ValueError("Input contains NaN")
#     105
#     106
#
# ValueError: Input contains NaN

# %%
mailchimp_mock2
# Out:
#                         Email Address First Name  Last Name Country  \
# 0             brodriguez369@gmail.com    Barbara  Rodriguez     USA
# 1    liamjones7027@stanfordalumni.org       Liam      Jones     USA
# 2      lindam7966@alumni.stanford.edu       Liam  Rodriguez     USA
# 3  liam.garcia7988@stanfordalumni.org       Liam     Garcia     USA
# 4               m.davis4650@gmail.com       Mary    Johnson     USA
#
#             handle
# 0    brodriguez369
# 1    liamjones7027
# 2       lindam7966
# 3  liam.garcia7988
# 4      m.davis4650

# %%
results_dict
# Out:
# {}

# %% [markdown]
# ### Pokemon Data

# %%
saa_poke = pd.read_excel('../data/SAA_Pokemon_FakeDB.xlsx')
saa_poke
# Filter necessary columns
saa_poke2 = saa_poke.filter(['home_country', 'home_email_address',\
                 'bus_email_address', 'first_name', 'last_name', 'email_switch',\
                'saa_email_address', 'gsb_email_address', 'other_email_address',])
saa_poke2
# Out:
#      home_country                           home_email_address  \
# 0               *                                          NaN
# 1           China               weedleg4046@stanfordalumni.org
# 2          Kuwait  aerodactyl.electric2974@alumni.stanford.edu
# 3             NaN                                            *
# 4             USA                                            *
# ...           ...                                          ...
# 3995        Japan                                            *
# 3996          NaN        kabutops.steel1285@stanfordalumni.org
# 3997       Kuwait                                            *
# 3998        Japan     larvitar.electric9778@stanfordalumni.org
# 3999          USA                                            *
#
#          bus_email_address  first_name last_name  \
# 0                      NaN   Growlithe       Ice
# 1                      NaN      Weedle     Grass
# 2                      NaN  Aerodactyl  Electric
# 3                      NaN      Pinsir      Fire
# 4                      NaN      Horsea       Ice
# ...                    ...         ...       ...
# 3995                   NaN    Smeargle  Electric
# 3996                   NaN    Kabutops     Steel
# 3997                   NaN    Slowking    Dragon
# 3998                   NaN    Larvitar  Electric
# 3999  u.dark7601@gmail.com    Ursaring      Dark
#
#                            email_switch                     saa_email_address  \
# 0                                   NaN                                     *
# 1                                   NaN       w.grass5053@alumni.stanford.edu
# 2                                   NaN                                     *
# 3              pinsirfire4582@gmail.com                                     *
# 4           hice7313@stanfordalumni.org                                   NaN
# ...                                 ...                                   ...
# 3995     smeargleelectric9444@gmail.com                                     *
# 3996    k.steel5317@alumni.stanford.edu                                   NaN
# 3997                                NaN      slowkingd5563@stanfordalumni.org
# 3998  l.electric7920@stanfordalumni.org                                   NaN
# 3999      u.dark1814@stanfordalumni.org  ursaring.dark7398@stanfordalumni.org
#
#      gsb_email_address  other_email_address
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
# ...                ...                  ...
# 3995               NaN                  NaN
# 3996               NaN                  NaN
# 3997               NaN                  NaN
# 3998               NaN                  NaN
# 3999               NaN                  NaN
#
# [4000 rows x 9 columns]

# %%
mailchimp_poke = pd.read_csv('../data/Fake_MailChimp_cleaned_Pokemon.csv')
mailchimp_poke
# Out:
#                          Email Address First Name Last Name  Board Member  \
# 0         slakoth.normal3945@gmail.com    Slakoth    Normal         False
# 1                 e.rock7454@gmail.com     Espeon      Rock          True
# 2  rhydonghost7966@alumni.stanford.edu     Rhydon     Ghost         False
# 3      porygong9247@stanfordalumni.org    Porygon     Grass         False
# 4           tangelagrass1376@gmail.com    Tangela     Grass         False
# 5             c.electric7518@gmail.com    Chansey     Steel          True
# 6          blissey.ghost4154@gmail.com    Blissey     Ghost         False
#
#   Gender      Chapter  Reunion Year  \
# 0    NaN        Texas           NaN
# 1      F      DC Area           NaN
# 2      M     Bay Area           NaN
# 3      M     Bay Area           NaN
# 4    NaN  New England           NaN
# 5      F     Other US           NaN
# 6      M  New England           NaN
#
#                                         Country Degree  MEMBER_RATING  \
# 0                                           USA    NaN            NaN
# 1                                 United States    NaN            NaN
# 2                                           USA    MBA            NaN
# 3                                         Japan     MS            NaN
# 4                                 United States    NaN            NaN
# 5                                           USA    NaN            NaN
# 6  Macao Special Administrative Region of China    NaN            NaN
#
#    OPTIN_TIME  OPTIN_IP  CONFIRM_TIME  CONFIRM_IP  LATITUDE  LONGITUDE  \
# 0         NaN       NaN           NaN         NaN       NaN        NaN
# 1         NaN       NaN           NaN         NaN       NaN        NaN
# 2         NaN       NaN           NaN         NaN       NaN        NaN
# 3         NaN       NaN           NaN         NaN       NaN        NaN
# 4         NaN       NaN           NaN         NaN       NaN        NaN
# 5         NaN       NaN           NaN         NaN       NaN        NaN
# 6         NaN       NaN           NaN         NaN       NaN        NaN
#
#    GMTOFF  DSTOFF  TIMEZONE  CC  REGION  CLEAN_TIME  CLEAN_CAMPAIGN_TITLE  \
# 0     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 1     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 2     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 3     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 4     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 5     NaN     NaN       NaN NaN     NaN         NaN                   NaN
# 6     NaN     NaN       NaN NaN     NaN         NaN                   NaN
#
#    CLEAN_CAMPAIGN_ID  LEID  EUID  NOTES  TAGS
# 0                NaN   NaN   NaN    NaN   NaN
# 1                NaN   NaN   NaN    NaN   NaN
# 2                NaN   NaN   NaN    NaN   NaN
# 3                NaN   NaN   NaN    NaN   NaN
# 4                NaN   NaN   NaN    NaN   NaN
# 5                NaN   NaN   NaN    NaN   NaN
# 6                NaN   NaN   NaN    NaN   NaN

# %%
# Filter necessary columns
mailchimp_poke2 = mailchimp_poke.filter(['Email Address', 'First Name', 'Last Name',\
                    'Country'])
mailchimp_poke2
# Out:
#                          Email Address First Name Last Name  \
# 0         slakoth.normal3945@gmail.com    Slakoth    Normal
# 1                 e.rock7454@gmail.com     Espeon      Rock
# 2  rhydonghost7966@alumni.stanford.edu     Rhydon     Ghost
# 3      porygong9247@stanfordalumni.org    Porygon     Grass
# 4           tangelagrass1376@gmail.com    Tangela     Grass
# 5             c.electric7518@gmail.com    Chansey     Steel
# 6          blissey.ghost4154@gmail.com    Blissey     Ghost
#
#                                         Country
# 0                                           USA
# 1                                 United States
# 2                                           USA
# 3                                         Japan
# 4                                 United States
# 5                                           USA
# 6  Macao Special Administrative Region of China

# %%
mailchimp_poke2['handle'] = mailchimp_poke2['Email Address'].str.split('@').str[0]
mailchimp_poke2
# Out:
#                          Email Address First Name Last Name  \
# 0         slakoth.normal3945@gmail.com    Slakoth    Normal
# 1                 e.rock7454@gmail.com     Espeon      Rock
# 2  rhydonghost7966@alumni.stanford.edu     Rhydon     Ghost
# 3      porygong9247@stanfordalumni.org    Porygon     Grass
# 4           tangelagrass1376@gmail.com    Tangela     Grass
# 5             c.electric7518@gmail.com    Chansey     Steel
# 6          blissey.ghost4154@gmail.com    Blissey     Ghost
#
#                                         Country              handle
# 0                                           USA  slakoth.normal3945
# 1                                 United States          e.rock7454
# 2                                           USA     rhydonghost7966
# 3                                         Japan        porygong9247
# 4                                 United States    tangelagrass1376
# 5                                           USA      c.electric7518
# 6  Macao Special Administrative Region of China   blissey.ghost4154

# %%
def ohe(df, column):    
    for col in column:
        train = df[[col]]
        ohe = OneHotEncoder(sparse=False, handle_unknown="error")
        ohe.fit(train)
        encoded_train = ohe.transform(train)
        col_names = [f"{col}_{f}" for f in ohe.get_feature_names()]
        encoded_train = pd.DataFrame(encoded_train,
                                     columns=col_names, index=df.index)
        df = pd.concat([df, encoded_train], axis=1)
        
    return df

# %%
saa_poke2.fillna(value='Not Available', inplace=True)
emails = ['home_email_address', 'bus_email_address', 'email_switch', 'saa_email_address',\
         'gsb_email_address', 'other_email_address']
handles = []
for x in emails:
    for i in range(0,saa_poke2.shape[0]):
        if '@' in saa_poke2[x][i]:
            saa_poke2[x+'_handle'] = saa_poke2[x].str.split('@').str[0]
        else:
            pass

# %%
emails
# Out:
# ['home_email_address',
#  'bus_email_address',
#  'email_switch',
#  'saa_email_address',
#  'gsb_email_address',
#  'other_email_address']

# %%
handles = []
for i in range(0,len(emails)):
    handles.append(emails[i]+'_handle')
handles
# Out:
# ['home_email_address_handle',
#  'bus_email_address_handle',
#  'email_switch_handle',
#  'saa_email_address_handle',
#  'gsb_email_address_handle',
#  'other_email_address_handle']

# %%
results_dict = {}
for i in range(0,mailchimp_poke2.shape[0]):
    target = mailchimp_poke2.iloc[i]
    target_dict = {'first_name': [target[1]], 'last_name': [target[2]],\
               emails[0]: [target[0]],\
               emails[1]: [target[0]],\
               emails[2]: [target[0]],\
               emails[3]: [target[0]],\
               emails[4]: [target[0]],\
               emails[5]: [target[0]],\
                   handles[0]: [target[4]],\
                   handles[1]: [target[4]],\
                   handles[2]: [target[4]],\
                   handles[3]: [target[4]],\
                   handles[4]: [target[4]],\
                   handles[5]: [target[4]],\
               'home_country': [target[3]]}
    df = pd.DataFrame.from_dict(target_dict)
    subset_saa = saa_poke2[saa_poke2['first_name'] == df.loc[0,'first_name']] 
    #the 0 is calling for row, so it does not return a series
    subset_saa_new = pd.concat([df,subset_saa], axis = 0).fillna(value='Not Available')
    ohe_df = ohe(subset_saa_new, subset_saa_new.columns)
    ohe_df.drop(columns = subset_saa_new.columns, inplace = True)
    y = np.array(ohe_df.iloc[0])
    y = y.reshape(1,-1)
    cos_sim = cosine_similarity(ohe_df, y)
    cos_sim = pd.DataFrame(data=cos_sim, index=ohe_df.index).sort_values(by=0, ascending=False) #[1:]
    results = list(cos_sim.index)
    results_df = subset_saa_new.loc[results]
    results_dict[i] = results_df

# %%
target[4]
# Out:
# 'blissey.ghost4154'

# %%
subset_saa_new
# Out:
#      first_name last_name               home_email_address  \
# 0       Blissey     Ghost      blissey.ghost4154@gmail.com
# 390     Blissey     Fairy    bfairy6293@stanfordalumni.org
# 600     Blissey     Ghost                    Not Available
# 754     Blissey      Rock                                *
# 802     Blissey     Steel                    Not Available
# 850     Blissey       Ice                    Not Available
# 858     Blissey      Rock                                *
# 977     Blissey       Ice                    Not Available
# 1430    Blissey      Rock                                *
# 1545    Blissey      Dark           blisseyd5981@gmail.com
# 1600    Blissey    Dragon                                *
# 1648    Blissey      Fire  blisseyf465@alumni.stanford.edu
# 1935    Blissey     Water                    Not Available
# 2402    Blissey       Ice               bice5800@gmail.com
# 3811    Blissey    Poison                    Not Available
#
#                          bus_email_address  \
# 0              blissey.ghost4154@gmail.com
# 390                          Not Available
# 600                          Not Available
# 754                          Not Available
# 802                          Not Available
# 850                          Not Available
# 858   blissey.rock4438@alumni.stanford.edu
# 977                          Not Available
# 1430                         Not Available
# 1545                         Not Available
# 1600                         Not Available
# 1648                         Not Available
# 1935   blisseywater628@alumni.stanford.edu
# 2402                         Not Available
# 3811                         Not Available
#
#                                email_switch  \
# 0               blissey.ghost4154@gmail.com
# 390                  blisseyf5884@gmail.com
# 600   blissey.ghost4154@alumni.stanford.edu
# 754         blisseyr2075@stanfordalumni.org
# 802         blisseys3334@stanfordalumni.org
# 850                      bice9725@gmail.com
# 858         blisseyr3225@stanfordalumni.org
# 977         blisseyi5337@stanfordalumni.org
# 1430                          Not Available
# 1545                          Not Available
# 1600                          Not Available
# 1648                          Not Available
# 1935        b.water9408@alumni.stanford.edu
# 2402                          Not Available
# 3811                          Not Available
#
#                         saa_email_address              gsb_email_address  \
# 0             blissey.ghost4154@gmail.com    blissey.ghost4154@gmail.com
# 390                         Not Available                  Not Available
# 600                                     *                  Not Available
# 754                         Not Available                  Not Available
# 802                                     *                  Not Available
# 850           bice7796@stanfordalumni.org                  Not Available
# 858                                     *                  Not Available
# 977                                     *  b.ice9706@alumni.stanford.edu
# 1430                        Not Available                  Not Available
# 1545                                    *                  Not Available
# 1600       bdragon9208@stanfordalumni.org                  Not Available
# 1648                                    *                  Not Available
# 1935        bwater5537@stanfordalumni.org                  Not Available
# 2402  blissey.ice4795@alumni.stanford.edu                  Not Available
# 3811                        Not Available                  Not Available
#
#               other_email_address home_email_address_handle  \
# 0     blissey.ghost4154@gmail.com         blissey.ghost4154
# 390                 Not Available                bfairy6293
# 600                 Not Available             Not Available
# 754                 Not Available                         *
# 802                 Not Available             Not Available
# 850                 Not Available             Not Available
# 858                 Not Available                         *
# 977                 Not Available             Not Available
# 1430                Not Available                         *
# 1545                Not Available              blisseyd5981
# 1600                Not Available                         *
# 1648                Not Available               blisseyf465
# 1935                Not Available             Not Available
# 2402                Not Available                  bice5800
# 3811                Not Available             Not Available
#
#      bus_email_address_handle email_switch_handle saa_email_address_handle  \
# 0           blissey.ghost4154   blissey.ghost4154        blissey.ghost4154
# 390             Not Available        blisseyf5884            Not Available
# 600             Not Available   blissey.ghost4154                        *
# 754             Not Available        blisseyr2075            Not Available
# 802             Not Available        blisseys3334                        *
# 850             Not Available            bice9725                 bice7796
# 858          blissey.rock4438        blisseyr3225                        *
# 977             Not Available        blisseyi5337                        *
# 1430            Not Available       Not Available            Not Available
# 1545            Not Available       Not Available                        *
# 1600            Not Available       Not Available              bdragon9208
# 1648            Not Available       Not Available                        *
# 1935          blisseywater628         b.water9408               bwater5537
# 2402            Not Available       Not Available          blissey.ice4795
# 3811            Not Available       Not Available            Not Available
#
#      gsb_email_address_handle other_email_address_handle  \
# 0           blissey.ghost4154          blissey.ghost4154
# 390             Not Available              Not Available
# 600             Not Available              Not Available
# 754             Not Available              Not Available
# 802             Not Available              Not Available
# 850             Not Available              Not Available
# 858             Not Available              Not Available
# 977                 b.ice9706              Not Available
# 1430            Not Available              Not Available
# 1545            Not Available              Not Available
# 1600            Not Available              Not Available
# 1648            Not Available              Not Available
# 1935            Not Available              Not Available
# 2402            Not Available              Not Available
# 3811            Not Available              Not Available
#
#                                       home_country
# 0     Macao Special Administrative Region of China
# 390                                         Kuwait
# 600                                            USA
# 754                                          China
# 802                                         Kuwait
# 850                                          Japan
# 858                                              *
# 977                                          China
# 1430                                           USA
# 1545                                        Kuwait
# 1600                                         Japan
# 1648                                           USA
# 1935                                         Japan
# 2402                                        Kuwait
# 3811                                 Not Available

# %%
mailchimp_poke2
# Out:
#                          Email Address First Name Last Name  \
# 0         slakoth.normal3945@gmail.com    Slakoth    Normal
# 1                 e.rock7454@gmail.com     Espeon      Rock
# 2  rhydonghost7966@alumni.stanford.edu     Rhydon     Ghost
# 3      porygong9247@stanfordalumni.org    Porygon     Grass
# 4           tangelagrass1376@gmail.com    Tangela     Grass
# 5             c.electric7518@gmail.com    Chansey     Steel
# 6          blissey.ghost4154@gmail.com    Blissey     Ghost
#
#                                         Country              handle
# 0                                           USA  slakoth.normal3945
# 1                                 United States          e.rock7454
# 2                                           USA     rhydonghost7966
# 3                                         Japan        porygong9247
# 4                                 United States    tangelagrass1376
# 5                                           USA      c.electric7518
# 6  Macao Special Administrative Region of China   blissey.ghost4154

# %%
name_first = input('First Name: ')

results_dict[mailchimp_poke2[mailchimp_poke2['First Name']
                             == name_first].index[0]].head(5)
# Out:
# First Name: Blissey
#     first_name last_name             home_email_address  \
# 0      Blissey     Ghost    blissey.ghost4154@gmail.com
# 600    Blissey     Ghost                  Not Available
# 390    Blissey     Fairy  bfairy6293@stanfordalumni.org
# 754    Blissey      Rock                              *
# 802    Blissey     Steel                  Not Available
#
#                bus_email_address                           email_switch  \
# 0    blissey.ghost4154@gmail.com            blissey.ghost4154@gmail.com
# 600                Not Available  blissey.ghost4154@alumni.stanford.edu
# 390                Not Available                 blisseyf5884@gmail.com
# 754                Not Available        blisseyr2075@stanfordalumni.org
# 802                Not Available        blisseys3334@stanfordalumni.org
#
#                saa_email_address            gsb_email_address  \
# 0    blissey.ghost4154@gmail.com  blissey.ghost4154@gmail.com
# 600                            *                Not Available
# 390                Not Available                Not Available
# 754                Not Available                Not Available
# 802                            *                Not Available
#
#              other_email_address home_email_address_handle  \
# 0    blissey.ghost4154@gmail.com         blissey.ghost4154
# 600                Not Available             Not Available
# 390                Not Available                bfairy6293
# 754                Not Available                         *
# 802                Not Available             Not Available
#
#     bus_email_address_handle email_switch_handle saa_email_address_handle  \
# 0          blissey.ghost4154   blissey.ghost4154        blissey.ghost4154
# 600            Not Available   blissey.ghost4154                        *
# 390            Not Available        blisseyf5884            Not Available
# 754            Not Available        blisseyr2075            Not Available
# 802            Not Available        blisseys3334                        *
#
#     gsb_email_address_handle other_email_address_handle  \
# 0          blissey.ghost4154          blissey.ghost4154
# 600            Not Available              Not Available
# 390            Not Available              Not Available
# 754            Not Available              Not Available
# 802            Not Available              Not Available
#
#                                      home_country
# 0    Macao Special Administrative Region of China
# 600                                           USA
# 390                                        Kuwait
# 754                                         China
# 802                                        Kuwait

# %%
results_df
# Out:
#      first_name last_name               home_email_address  \
# 0       Blissey     Ghost      blissey.ghost4154@gmail.com
# 600     Blissey     Ghost                    Not Available
# 390     Blissey     Fairy    bfairy6293@stanfordalumni.org
# 754     Blissey      Rock                                *
# 802     Blissey     Steel                    Not Available
# 850     Blissey       Ice                    Not Available
# 858     Blissey      Rock                                *
# 977     Blissey       Ice                    Not Available
# 1430    Blissey      Rock                                *
# 1545    Blissey      Dark           blisseyd5981@gmail.com
# 1600    Blissey    Dragon                                *
# 1648    Blissey      Fire  blisseyf465@alumni.stanford.edu
# 1935    Blissey     Water                    Not Available
# 2402    Blissey       Ice               bice5800@gmail.com
# 3811    Blissey    Poison                    Not Available
#
#                          bus_email_address  \
# 0              blissey.ghost4154@gmail.com
# 600                          Not Available
# 390                          Not Available
# 754                          Not Available
# 802                          Not Available
# 850                          Not Available
# 858   blissey.rock4438@alumni.stanford.edu
# 977                          Not Available
# 1430                         Not Available
# 1545                         Not Available
# 1600                         Not Available
# 1648                         Not Available
# 1935   blisseywater628@alumni.stanford.edu
# 2402                         Not Available
# 3811                         Not Available
#
#                                email_switch  \
# 0               blissey.ghost4154@gmail.com
# 600   blissey.ghost4154@alumni.stanford.edu
# 390                  blisseyf5884@gmail.com
# 754         blisseyr2075@stanfordalumni.org
# 802         blisseys3334@stanfordalumni.org
# 850                      bice9725@gmail.com
# 858         blisseyr3225@stanfordalumni.org
# 977         blisseyi5337@stanfordalumni.org
# 1430                          Not Available
# 1545                          Not Available
# 1600                          Not Available
# 1648                          Not Available
# 1935        b.water9408@alumni.stanford.edu
# 2402                          Not Available
# 3811                          Not Available
#
#                         saa_email_address              gsb_email_address  \
# 0             blissey.ghost4154@gmail.com    blissey.ghost4154@gmail.com
# 600                                     *                  Not Available
# 390                         Not Available                  Not Available
# 754                         Not Available                  Not Available
# 802                                     *                  Not Available
# 850           bice7796@stanfordalumni.org                  Not Available
# 858                                     *                  Not Available
# 977                                     *  b.ice9706@alumni.stanford.edu
# 1430                        Not Available                  Not Available
# 1545                                    *                  Not Available
# 1600       bdragon9208@stanfordalumni.org                  Not Available
# 1648                                    *                  Not Available
# 1935        bwater5537@stanfordalumni.org                  Not Available
# 2402  blissey.ice4795@alumni.stanford.edu                  Not Available
# 3811                        Not Available                  Not Available
#
#               other_email_address home_email_address_handle  \
# 0     blissey.ghost4154@gmail.com         blissey.ghost4154
# 600                 Not Available             Not Available
# 390                 Not Available                bfairy6293
# 754                 Not Available                         *
# 802                 Not Available             Not Available
# 850                 Not Available             Not Available
# 858                 Not Available                         *
# 977                 Not Available             Not Available
# 1430                Not Available                         *
# 1545                Not Available              blisseyd5981
# 1600                Not Available                         *
# 1648                Not Available               blisseyf465
# 1935                Not Available             Not Available
# 2402                Not Available                  bice5800
# 3811                Not Available             Not Available
#
#      bus_email_address_handle email_switch_handle saa_email_address_handle  \
# 0           blissey.ghost4154   blissey.ghost4154        blissey.ghost4154
# 600             Not Available   blissey.ghost4154                        *
# 390             Not Available        blisseyf5884            Not Available
# 754             Not Available        blisseyr2075            Not Available
# 802             Not Available        blisseys3334                        *
# 850             Not Available            bice9725                 bice7796
# 858          blissey.rock4438        blisseyr3225                        *
# 977             Not Available        blisseyi5337                        *
# 1430            Not Available       Not Available            Not Available
# 1545            Not Available       Not Available                        *
# 1600            Not Available       Not Available              bdragon9208
# 1648            Not Available       Not Available                        *
# 1935          blisseywater628         b.water9408               bwater5537
# 2402            Not Available       Not Available          blissey.ice4795
# 3811            Not Available       Not Available            Not Available
#
#      gsb_email_address_handle other_email_address_handle  \
# 0           blissey.ghost4154          blissey.ghost4154
# 600             Not Available              Not Available
# 390             Not Available              Not Available
# 754             Not Available              Not Available
# 802             Not Available              Not Available
# 850             Not Available              Not Available
# 858             Not Available              Not Available
# 977                 b.ice9706              Not Available
# 1430            Not Available              Not Available
# 1545            Not Available              Not Available
# 1600            Not Available              Not Available
# 1648            Not Available              Not Available
# 1935            Not Available              Not Available
# 2402            Not Available              Not Available
# 3811            Not Available              Not Available
#
#                                       home_country
# 0     Macao Special Administrative Region of China
# 600                                            USA
# 390                                         Kuwait
# 754                                          China
# 802                                         Kuwait
# 850                                          Japan
# 858                                              *
# 977                                          China
# 1430                                           USA
# 1545                                        Kuwait
# 1600                                         Japan
# 1648                                           USA
# 1935                                         Japan
# 2402                                        Kuwait
# 3811                                 Not Available

# %% [markdown]
# ## Scratchwork

# %%
if str(combined_data['email_switch']).find('(pref)'):
    combined_data['Email Address'] = combined_data['email_switch']

# %%
if '(pref)' not in combined_data['email_switch']: 
    pass
else:
    combined_data['Email Address'] = combined_data['email_switch']

# %%
name_first = input('First Name: ')
name_last = input('Last Name: ')
pref_email = input('Preferred Email Address: ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-5243e531f0b0> in <module>
# ----> 1 name_first = input('First Name: ')
#       2 name_last = input('Last Name: ')
#       3 pref_email = input('Preferred Email Address: ')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def create_df(name1, name2, email):
    new_df = pd.DataFrame(columns=['First_Name', 'Last_Name', 'Preferred_Email'])
    df2 = {'First_Name': name1, 'Last_Name': name2, 'Preferred_Email': email}
    new_df = new_df.append(df2, ignore_index = True)
    return new_df

# %%
df = create_df(name_first, name_last, pref_email)
df

# %%
df2 = {'First Name': 'Harry', 'Last Name': 'Potter', 'Email Address': 'email@email.com'}
combined_data = combined_data.append(df2, ignore_index = True)
combined_data

# %%
df2 = {'First Name': 'Walter', 'Last Name': 'White', 'Email Address': 'science@stanford.edu'}
combined_data = combined_data.append(df2, ignore_index = True)
combined_data

# %%
def update_df(df, name1, name2, email):
    df.at[df.set_index('Email Address').loc[email]['First Name']] = name1
    df.at[df.set_index('First Name').loc[name1]['Preferred Email Address']] = email
    df.at[df.set_index('First Name').loc[name1]['Last Name']] = name2
    return df

# %%
# sub_set = saa_mock.sample(frac=.25, random_state=42)
# sub_set

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Next step would be to take a proactive approach to mitigate the number of emails that bounce in the future. I would suggest using the salesforce dataset to check for recent grads to reach out before they lose their student emails and ask for updated contact information and their subsequent plans after graduation. It would be easier to update records proactively when we still have accurate contact information. For subsequent plans after graduation, this would be to keeping location information of members to more accurately send regional events and functions.
