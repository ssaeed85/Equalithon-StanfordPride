# %%
import pandas as pd
import numpy as np

# %%
mailchimp_data = pd.read_csv('./MailChimp_cleaned_records_headers.csv')
pd.set_option('max_columns', None)
mailchimp_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS]
# Index: []

# %%
# mailchimp_data.drop(['Board Member', 'Gender', 'Reunion Year',\
#                      'Country', 'Degree', 'MEMBER_RATING',\
#                      'OPTIN_TIME', 'OPTIN_IP', 'CONFIRM_TIME',\
#                      'CONFIRM_IP', 'LATITUDE','LONGITUDE', 'GMTOFF',\
#                      'DSTOFF', 'TIMEZONE', 'CC', 'REGION', 'LEID',\
#                      'EUID', 'NOTES', 'TAGS'], axis =1, inplace=True)
# mailchimp_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Chapter, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID]
# Index: []

# %% [markdown]
# The mailchimp dataset comes from the salesforce dataset. This Cleaned dataset would only include emails that have bounced for one reason or another. It will not include any members who have opted out of the email service or those that are receiving emails without any complications. It is important to note that updating information within salesforce for those who have opted out may re-instantiate the email services so we are specifically working with cleaned/bounced records. Additionally, the datasets created for those who are Subscribed and Unsubscribed will have different column names than the Cleaned dataset here (ie Clean_Time, Clean_campaign_title, ect). Therefore any function created here may not work for those datasets.

# %%
saa_pride_data = pd.read_excel('./SAA Pride member reports headings.xlsx')
saa_pride_data.reset_index(inplace = True)
saa_pride_data
# Out:
# Empty DataFrame
# Columns: [index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
# saa_pride_data.drop(['home_country', 'home_phone_area_code',\
#                      'home_phone_number', 'bus_city', 'bus_state_code',\
#                     'bus_country', 'bus_phone_area_code',\
#                      'bus_phone_number', 'bus_email_address',
#                     'pref_phone_area_code', 'pref_phone_addr_type',
#                     'memb_status_desc', 'parent_degree_string', \
#                     'short_degree_string_spouse', 
#                      'parent_degree_string_spouse', 'primary_sort_name',\
#                     'plan_name', 'primary_ind'], axis =1, inplace=True)
# saa_pride_data
# Out:
# Empty DataFrame
# Columns: [pref_mail_name, pref_class_year, home_city, home_state_code, home_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_number, short_degree_string]
# Index: []

# %% [markdown]
# The Stanford Alumni Association has it's own dataset that may or may not have additional or more recent data on some of the members. It may also have outdated data. Students are given an email but when they become alumni the email needs to be updated. Whether it is updated to specifically an 'alumni.stanford.edu' address or to another would be at the students discrepancy and isn't always updated.

# %%
combined_data = mailchimp_data.merge(saa_pride_data,\
                                     left_on =['First Name', 'Last Name'],\
                                     right_on=['first_name', 'last_name'],\
                                     how='outer')
combined_data
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
saa_pride_data
# Out:
# Empty DataFrame
# Columns: [index, pref_mail_name, pref_class_year, home_city, home_state_code, home_country, home_phone_area_code, home_phone_number, home_email_address, bus_city, bus_state_code, bus_country, bus_phone_area_code, bus_phone_number, bus_email_address, first_name, last_name, pref_name_sort, email_switch, saa_email_address, gsb_email_address, other_email_address, pref_phone_area_code, pref_phone_number, pref_phone_addr_type, memb_status_desc, short_degree_string, parent_degree_string, short_degree_string_spouse, parent_degree_string_spouse, primary_sort_name, plan_name, primary_ind]
# Index: []

# %%
saa_mock = pd.read_excel('../data/SAA_FakeDB.xlsx')
saa_mock
# Out:
#     pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 0              NaN              NaN    London             NaN          NaN
# 1              NaN              NaN    Madrid             NaN        Japan
# 2              NaN              NaN  Shanghai             NaN          USA
# 3              NaN              NaN   Chicago              IL          UAE
# 4              NaN           1994.0     Seoul             NaN            *
# ..             ...              ...       ...             ...          ...
# 95             NaN              NaN   Beijing             NaN          UAE
# 96             NaN              NaN     Seoul             NaN          UAE
# 97             NaN              NaN   Beijing             NaN          UAE
# 98             NaN           2011.0       NaN             NaN            *
# 99             NaN              NaN  Shanghai             NaN            *
#
#     home_phone_area_code home_phone_number                home_email_address  \
# 0                    NaN               NaN                                 *
# 1                    NaN               NaN                                 *
# 2                    NaN      898 7073-217                               NaN
# 3                    NaN               NaN                               NaN
# 4                    NaN               NaN                               NaN
# ..                   ...               ...                               ...
# 95                   NaN               NaN                               NaN
# 96                   NaN               NaN                                 *
# 97                   NaN               NaN  elizabeth.martinez6250@gmail.com
# 98                   NaN               NaN     sbrown7443@stanfordalumni.org
# 99                   NaN                 *                               NaN
#
#     bus_city  bus_state_code bus_country  bus_phone_area_code  \
# 0        NaN             NaN      Kuwait                  NaN
# 1        NaN             NaN         NaN                  NaN
# 2        NaN             NaN         UAE                  NaN
# 3        NaN             NaN       China                  NaN
# 4        NaN             NaN         NaN                  NaN
# ..       ...             ...         ...                  ...
# 95       NaN             NaN         USA                  NaN
# 96       NaN             NaN      Kuwait                  NaN
# 97       NaN             NaN       Japan                  NaN
# 98       NaN             NaN       Japan                  NaN
# 99       NaN             NaN         NaN                  NaN
#
#     bus_phone_number bus_email_address first_name  last_name  pref_name_sort  \
# 0                NaN               NaN      Linda      Brown             NaN
# 1                NaN               NaN       Mary  Rodriguez             NaN
# 2                NaN               NaN      Sarah  Rodriguez             NaN
# 3                NaN               NaN    Jessica      Jones             NaN
# 4                NaN               NaN    Jessica   Martinez             NaN
# ..               ...               ...        ...        ...             ...
# 95               NaN               NaN     Oliver  Rodriguez             NaN
# 96               NaN               NaN      James      Brown             NaN
# 97               NaN               NaN  Elizabeth   Martinez             NaN
# 98               NaN               NaN      Sarah      Brown             NaN
# 99               NaN               NaN  Elizabeth      Smith             NaN
#
#     email_switch                        saa_email_address gsb_email_address  \
# 0            NaN           lindab1567@alumni.stanford.edu               NaN
# 1            NaN                                        *               NaN
# 2            NaN   sarah.rodriguez992@alumni.stanford.edu               NaN
# 3            NaN         jessicaj5803@alumni.stanford.edu               NaN
# 4            NaN  jessicamartinez1707@alumni.stanford.edu               NaN
# ..           ...                                      ...               ...
# 95           NaN                                        *               NaN
# 96           NaN                                        *               NaN
# 97           NaN                                      NaN               NaN
# 98           NaN           sarahb7790@alumni.stanford.edu               NaN
# 99           NaN                                      NaN               NaN
#
#     other_email_address  pref_phone_area_code  pref_phone_number  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   NaN                   NaN                NaN
# 3                   NaN                   NaN                NaN
# 4                   NaN                   NaN                NaN
# ..                  ...                   ...                ...
# 95                  NaN                   NaN                NaN
# 96                  NaN                   NaN                NaN
# 97                  NaN                   NaN                NaN
# 98                  NaN                   NaN                NaN
# 99                  NaN                   NaN                NaN
#
#     pref_phone_addr_type  memb_status_desc     short_degree_string  \
# 0                    NaN               NaN         PhD '94, BA '82
# 1                    NaN               NaN          MA '85, BS '92
# 2                    NaN               NaN  BS '88, BS '95, MA '85
# 3                    NaN               NaN                 MBA '81
# 4                    NaN               NaN                     NaN
# ..                   ...               ...                     ...
# 95                   NaN               NaN                     NaN
# 96                   NaN               NaN          BS '94, MS '92
# 97                   NaN               NaN       '85, MBA '87, '92
# 98                   NaN               NaN         PhD '84, MS '91
# 99                   NaN               NaN                  MS '83
#
#     parent_degree_string  short_degree_string_spouse  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
# ..                   ...                         ...
# 95                   NaN                         NaN
# 96                   NaN                         NaN
# 97                   NaN                         NaN
# 98                   NaN                         NaN
# 99                   NaN                         NaN
#
#     parent_degree_string_spouse  primary_sort_name  plan_name  primary_ind   0
# 0                           NaN                NaN        NaN          NaN NaN
# 1                           NaN                NaN        NaN          NaN NaN
# 2                           NaN                NaN        NaN          NaN NaN
# 3                           NaN                NaN        NaN          NaN NaN
# 4                           NaN                NaN        NaN          NaN NaN
# ..                          ...                ...        ...          ...  ..
# 95                          NaN                NaN        NaN          NaN NaN
# 96                          NaN                NaN        NaN          NaN NaN
# 97                          NaN                NaN        NaN          NaN NaN
# 98                          NaN                NaN        NaN          NaN NaN
# 99                          NaN                NaN        NaN          NaN NaN
#
# [100 rows x 33 columns]

# %% [markdown]
# A random mock dataset was produced from the format of the SAA database for a proof of concept.

# %%
sub_set = saa_mock.sample(frac=.25, random_state=42)
sub_set
# Out:
#     pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 83             NaN           1992.0    Madrid             NaN        China
# 53             NaN           1996.0   Chicago              IL          NaN
# 70             NaN              NaN     Dubai             NaN          NaN
# 45             NaN              NaN    Madrid             NaN          NaN
# 44             NaN              NaN         *               *          USA
# 39             NaN           2001.0     Dubai             NaN          USA
# 22             NaN              NaN     Tokyo             NaN        China
# 80             NaN              NaN   Beijing             NaN          USA
# 10             NaN           1996.0         *               *        China
# 0              NaN              NaN    London             NaN          NaN
# 18             NaN              NaN    London             NaN          UAE
# 30             NaN              NaN  Shanghai             NaN        China
# 73             NaN           1991.0     Dubai             NaN          USA
# 33             NaN              NaN  Shanghai             NaN            *
# 90             NaN              NaN         *               *          NaN
# 4              NaN           1994.0     Seoul             NaN            *
# 76             NaN              NaN       NaN             NaN          UAE
# 77             NaN              NaN         *               *        Japan
# 12             NaN              NaN    Madrid             NaN          NaN
# 31             NaN              NaN         *               *          NaN
# 55             NaN              NaN    Boston              MA       Kuwait
# 88             NaN              NaN    Boston              MA        Japan
# 26             NaN           2006.0     Dubai             NaN       Kuwait
# 42             NaN           1998.0         *               *          NaN
# 69             NaN           2016.0   Beijing             NaN          NaN
#
#     home_phone_area_code home_phone_number  \
# 83                   NaN                 *
# 53                   NaN               NaN
# 70                   NaN               NaN
# 45                   NaN      218 8332-531
# 44                   NaN                 *
# 39                   NaN               NaN
# 22                   NaN               NaN
# 80                   NaN               NaN
# 10                   NaN                 *
# 0                    NaN               NaN
# 18                   NaN                 *
# 30                   NaN               NaN
# 73                   NaN                 *
# 33                   NaN      527 8201-677
# 90                   NaN               NaN
# 4                    NaN               NaN
# 76                   NaN               NaN
# 77                   NaN                 *
# 12                   NaN                 *
# 31                   NaN                 *
# 55                   NaN               NaN
# 88                   NaN                 *
# 26                   NaN                 *
# 42                   NaN               NaN
# 69                   NaN                 *
#
#                         home_email_address  bus_city  bus_state_code  \
# 83                                       *       NaN             NaN
# 53                                     NaN       NaN             NaN
# 70                                     NaN       NaN             NaN
# 45                                     NaN       NaN             NaN
# 44            jjones433@stanfordalumni.org       NaN             NaN
# 39                     noahj7448@gmail.com       NaN             NaN
# 22                   elijahm5586@gmail.com       NaN             NaN
# 80     l.rodriguez4305@alumni.stanford.edu       NaN             NaN
# 10        ewilliams4568@stanfordalumni.org       NaN             NaN
# 0                                        *       NaN             NaN
# 18                marymiller5944@gmail.com       NaN             NaN
# 30                                     NaN       NaN             NaN
# 73        brodriguez369@stanfordalumni.org       NaN             NaN
# 33                                       *       NaN             NaN
# 90       susanbrown9774@stanfordalumni.org       NaN             NaN
# 4                                      NaN       NaN             NaN
# 76                                       *       NaN             NaN
# 77                                       *       NaN             NaN
# 12                     mdavis343@gmail.com       NaN             NaN
# 31                                     NaN       NaN             NaN
# 55  jennifer.garcia9830@stanfordalumni.org       NaN             NaN
# 88                                       *       NaN             NaN
# 26                                     NaN       NaN             NaN
# 42  sarah.rodriguez4470@stanfordalumni.org       NaN             NaN
# 69                                     NaN       NaN             NaN
#
#       bus_country  bus_phone_area_code  bus_phone_number  \
# 83            USA                  NaN               NaN
# 53            NaN                  NaN               NaN
# 70  United States                  NaN               NaN
# 45         Kuwait                  NaN               NaN
# 44            NaN                  NaN               NaN
# 39          Japan                  NaN               NaN
# 22            UAE                  NaN               NaN
# 80            UAE                  NaN               NaN
# 10            NaN                  NaN               NaN
# 0          Kuwait                  NaN               NaN
# 18         Kuwait                  NaN               NaN
# 30         Kuwait                  NaN               NaN
# 73  United States                  NaN               NaN
# 33            NaN                  NaN               NaN
# 90         Kuwait                  NaN               NaN
# 4             NaN                  NaN               NaN
# 76            NaN                  NaN               NaN
# 77  United States                  NaN               NaN
# 12            NaN                  NaN               NaN
# 31            USA                  NaN               NaN
# 55            UAE                  NaN               NaN
# 88            NaN                  NaN               NaN
# 26            NaN                  NaN               NaN
# 42          China                  NaN               NaN
# 69            NaN                  NaN               NaN
#
#                        bus_email_address first_name  last_name  \
# 83                                   NaN   Patricia     Miller
# 53        h.smith2476@stanfordalumni.org      Henry      Smith
# 70                                   NaN      Sarah   Williams
# 45         lucasr8138@stanfordalumni.org      Lucas  Rodriguez
# 44                                   NaN      James      Jones
# 39                                   NaN       Noah      Jones
# 22                                   NaN     Elijah     Miller
# 80    lrodriguez3310@alumni.stanford.edu      Lucas  Rodriguez
# 10                                   NaN     Elijah   Williams
# 0                                    NaN      Linda      Brown
# 18   mary.miller5372@alumni.stanford.edu       Mary     Miller
# 30  liamrodriguez3500@stanfordalumni.org       Liam  Rodriguez
# 73                                   NaN    Barbara  Rodriguez
# 33                                   NaN      Susan    Johnson
# 90                                   NaN      Susan      Brown
# 4                                    NaN    Jessica   Martinez
# 76                                   NaN    Barbara  Rodriguez
# 77                                   NaN      James   Martinez
# 12                                   NaN       Mary      Davis
# 31                                   NaN      Sarah      Jones
# 55                                   NaN   Jennifer     Garcia
# 88                sjohnson4098@gmail.com      Sarah    Johnson
# 26                                   NaN      Sarah      Jones
# 42                                   NaN      Sarah  Rodriguez
# 69                                   NaN      Susan  Rodriguez
#
#     pref_name_sort  email_switch                         saa_email_address  \
# 83             NaN           NaN           pmiller7922@alumni.stanford.edu
# 53             NaN           NaN              henrys723@stanfordalumni.org
# 70             NaN           NaN                                         *
# 45             NaN           NaN                                       NaN
# 44             NaN           NaN                                         *
# 39             NaN           NaN            n.jones5978@stanfordalumni.org
# 22             NaN           NaN       elijahmiller4203@stanfordalumni.org
# 80             NaN           NaN     lucasrodriguez2772@stanfordalumni.org
# 10             NaN           NaN                                       NaN
# 0              NaN           NaN            lindab1567@alumni.stanford.edu
# 18             NaN           NaN                                       NaN
# 30             NaN           NaN     liam.rodriguez8596@stanfordalumni.org
# 73             NaN           NaN  barbara.rodriguez5922@stanfordalumni.org
# 33             NaN           NaN                                       NaN
# 90             NaN           NaN                                       NaN
# 4              NaN           NaN   jessicamartinez1707@alumni.stanford.edu
# 76             NaN           NaN  barbara.rodriguez2112@stanfordalumni.org
# 77             NaN           NaN                                         *
# 12             NaN           NaN            m.davis4650@stanfordalumni.org
# 31             NaN           NaN             sarahj4644@stanfordalumni.org
# 55             NaN           NaN     jennifergarcia736@alumni.stanford.edu
# 88             NaN           NaN                                       NaN
# 26             NaN           NaN            sjones7414@alumni.stanford.edu
# 42             NaN           NaN        srodriguez2665@alumni.stanford.edu
# 69             NaN           NaN                                       NaN
#
#                      gsb_email_address  other_email_address  \
# 83                                 NaN                  NaN
# 53                                 NaN                  NaN
# 70                                 NaN                  NaN
# 45                                 NaN                  NaN
# 44                                 NaN                  NaN
# 39                                 NaN                  NaN
# 22                                 NaN                  NaN
# 80                                 NaN                  NaN
# 10                                 NaN                  NaN
# 0                                  NaN                  NaN
# 18                                 NaN                  NaN
# 30                                 NaN                  NaN
# 73  brodriguez2537@alumni.stanford.edu                  NaN
# 33                                 NaN                  NaN
# 90                                 NaN                  NaN
# 4                                  NaN                  NaN
# 76                                 NaN                  NaN
# 77                                 NaN                  NaN
# 12                                 NaN                  NaN
# 31                                 NaN                  NaN
# 55                                 NaN                  NaN
# 88                                 NaN                  NaN
# 26                                 NaN                  NaN
# 42                                 NaN                  NaN
# 69                                 NaN                  NaN
#
#     pref_phone_area_code  pref_phone_number  pref_phone_addr_type  \
# 83                   NaN                NaN                   NaN
# 53                   NaN                NaN                   NaN
# 70                   NaN                NaN                   NaN
# 45                   NaN                NaN                   NaN
# 44                   NaN                NaN                   NaN
# 39                   NaN                NaN                   NaN
# 22                   NaN                NaN                   NaN
# 80                   NaN                NaN                   NaN
# 10                   NaN                NaN                   NaN
# 0                    NaN                NaN                   NaN
# 18                   NaN                NaN                   NaN
# 30                   NaN                NaN                   NaN
# 73                   NaN                NaN                   NaN
# 33                   NaN                NaN                   NaN
# 90                   NaN                NaN                   NaN
# 4                    NaN                NaN                   NaN
# 76                   NaN                NaN                   NaN
# 77                   NaN                NaN                   NaN
# 12                   NaN                NaN                   NaN
# 31                   NaN                NaN                   NaN
# 55                   NaN                NaN                   NaN
# 88                   NaN                NaN                   NaN
# 26                   NaN                NaN                   NaN
# 42                   NaN                NaN                   NaN
# 69                   NaN                NaN                   NaN
#
#     memb_status_desc      short_degree_string  parent_degree_string  \
# 83               NaN                   JD '80                   NaN
# 53               NaN                      NaN                   NaN
# 70               NaN                   BA '81                   NaN
# 45               NaN  PhD '97, MS '93, MA '96                   NaN
# 44               NaN           BA '83, JD '97                   NaN
# 39               NaN           BA '92, JD '89                   NaN
# 22               NaN           JD '97, JD '91                   NaN
# 80               NaN                      NaN                   NaN
# 10               NaN      JD '87, BS '91, '84                   NaN
# 0                NaN          PhD '94, BA '82                   NaN
# 18               NaN   BA '94, JD '83, MA '80                   NaN
# 30               NaN  PhD '83, MD '99, MA '86                   NaN
# 73               NaN                      NaN                   NaN
# 33               NaN                      NaN                   NaN
# 90               NaN                      NaN                   NaN
# 4                NaN                      NaN                   NaN
# 76               NaN                      '97                   NaN
# 77               NaN                      NaN                   NaN
# 12               NaN                      NaN                   NaN
# 31               NaN   JD '86, BA '86, BS '83                   NaN
# 55               NaN           JD '86, BA '87                   NaN
# 88               NaN   BS '94, BA '93, BS '80                   NaN
# 26               NaN              '89, BA '96                   NaN
# 42               NaN                  PhD '86                   NaN
# 69               NaN   MS '97, BA '83, MD '94                   NaN
#
#     short_degree_string_spouse  parent_degree_string_spouse  \
# 83                         NaN                          NaN
# 53                         NaN                          NaN
# 70                         NaN                          NaN
# 45                         NaN                          NaN
# 44                         NaN                          NaN
# 39                         NaN                          NaN
# 22                         NaN                          NaN
# 80                         NaN                          NaN
# 10                         NaN                          NaN
# 0                          NaN                          NaN
# 18                         NaN                          NaN
# 30                         NaN                          NaN
# 73                         NaN                          NaN
# 33                         NaN                          NaN
# 90                         NaN                          NaN
# 4                          NaN                          NaN
# 76                         NaN                          NaN
# 77                         NaN                          NaN
# 12                         NaN                          NaN
# 31                         NaN                          NaN
# 55                         NaN                          NaN
# 88                         NaN                          NaN
# 26                         NaN                          NaN
# 42                         NaN                          NaN
# 69                         NaN                          NaN
#
#     primary_sort_name  plan_name  primary_ind   0
# 83                NaN        NaN          NaN NaN
# 53                NaN        NaN          NaN NaN
# 70                NaN        NaN          NaN NaN
# 45                NaN        NaN          NaN NaN
# 44                NaN        NaN          NaN NaN
# 39                NaN        NaN          NaN NaN
# 22                NaN        NaN          NaN NaN
# 80                NaN        NaN          NaN NaN
# 10                NaN        NaN          NaN NaN
# 0                 NaN        NaN          NaN NaN
# 18                NaN        NaN          NaN NaN
# 30                NaN        NaN          NaN NaN
# 73                NaN        NaN          NaN NaN
# 33                NaN        NaN          NaN NaN
# 90                NaN        NaN          NaN NaN
# 4                 NaN        NaN          NaN NaN
# 76                NaN        NaN          NaN NaN
# 77                NaN        NaN          NaN NaN
# 12                NaN        NaN          NaN NaN
# 31                NaN        NaN          NaN NaN
# 55                NaN        NaN          NaN NaN
# 88                NaN        NaN          NaN NaN
# 26                NaN        NaN          NaN NaN
# 42                NaN        NaN          NaN NaN
# 69                NaN        NaN          NaN NaN

# %% [markdown]
# ## Scratchwork

# %%
if str(combined_data['email_switch']).find('(pref)'):
    combined_data['Email Address'] = combined_data['email_switch']

# %%
if '(pref)' not in combined_data['email_switch']: 
    pass
else:
    combined_data['Email Address'] = combined_data['email_switch']

# %%
name_first = input('First Name: ')
name_last = input('Last Name: ')
pref_email = input('Preferred Email Address: ')
# Out:
# First Name: Ash
# Last Name: Ketchum
# Preferred Email Address: Poke1@gmail.com

# %%
def create_df(name1, name2, email):
    new_df = pd.DataFrame(columns=['First_Name', 'Last_Name', 'Preferred_Email'])
    df2 = {'First_Name': name1, 'Last_Name': name2, 'Preferred_Email': email}
    new_df = new_df.append(df2, ignore_index = True)
    return new_df

# %%
df = create_df(name_first, name_last, pref_email)
df
# Out:
#   First_Name Last_Name  Preferred_Email
# 0        Ash   Ketchum  Poke1@gmail.com

# %%
df2 = {'First Name': 'Harry', 'Last Name': 'Potter', 'Email Address': 'email@email.com'}
combined_data = combined_data.append(df2, ignore_index = True)
combined_data
# Out:
#      Email Address First Name Last Name Board Member Gender Chapter  \
# 0  email@email.com      Harry    Potter          NaN    NaN     NaN
#
#   Reunion Year Country Degree MEMBER_RATING OPTIN_TIME OPTIN_IP CONFIRM_TIME  \
# 0          NaN     NaN    NaN           NaN        NaN      NaN          NaN
#
#   CONFIRM_IP LATITUDE LONGITUDE GMTOFF DSTOFF TIMEZONE   CC REGION CLEAN_TIME  \
# 0        NaN      NaN       NaN    NaN    NaN      NaN  NaN    NaN        NaN
#
#   CLEAN_CAMPAIGN_TITLE CLEAN_CAMPAIGN_ID LEID EUID NOTES TAGS pref_mail_name  \
# 0                  NaN               NaN  NaN  NaN   NaN  NaN            NaN
#
#   pref_class_year home_city home_state_code home_country home_phone_area_code  \
# 0             NaN       NaN             NaN          NaN                  NaN
#
#   home_phone_number home_email_address bus_city bus_state_code bus_country  \
# 0               NaN                NaN      NaN            NaN         NaN
#
#   bus_phone_area_code bus_phone_number bus_email_address first_name last_name  \
# 0                 NaN              NaN               NaN        NaN       NaN
#
#   pref_name_sort email_switch saa_email_address gsb_email_address  \
# 0            NaN          NaN               NaN               NaN
#
#   other_email_address pref_phone_area_code pref_phone_number  \
# 0                 NaN                  NaN               NaN
#
#   pref_phone_addr_type memb_status_desc short_degree_string  \
# 0                  NaN              NaN                 NaN
#
#   parent_degree_string short_degree_string_spouse parent_degree_string_spouse  \
# 0                  NaN                        NaN                         NaN
#
#   primary_sort_name plan_name primary_ind
# 0               NaN       NaN         NaN

# %%
df2 = {'First Name': 'Walter', 'Last Name': 'White', 'Email Address': 'science@stanford.edu'}
combined_data = combined_data.append(df2, ignore_index = True)
combined_data
# Out:
#           Email Address First Name Last Name Board Member Gender Chapter  \
# 0       email@email.com      Harry    Potter          NaN    NaN     NaN
# 1  science@stanford.edu     Walter     White          NaN    NaN     NaN
#
#   Reunion Year Country Degree MEMBER_RATING OPTIN_TIME OPTIN_IP CONFIRM_TIME  \
# 0          NaN     NaN    NaN           NaN        NaN      NaN          NaN
# 1          NaN     NaN    NaN           NaN        NaN      NaN          NaN
#
#   CONFIRM_IP LATITUDE LONGITUDE GMTOFF DSTOFF TIMEZONE   CC REGION CLEAN_TIME  \
# 0        NaN      NaN       NaN    NaN    NaN      NaN  NaN    NaN        NaN
# 1        NaN      NaN       NaN    NaN    NaN      NaN  NaN    NaN        NaN
#
#   CLEAN_CAMPAIGN_TITLE CLEAN_CAMPAIGN_ID LEID EUID NOTES TAGS pref_mail_name  \
# 0                  NaN               NaN  NaN  NaN   NaN  NaN            NaN
# 1                  NaN               NaN  NaN  NaN   NaN  NaN            NaN
#
#   pref_class_year home_city home_state_code home_country home_phone_area_code  \
# 0             NaN       NaN             NaN          NaN                  NaN
# 1             NaN       NaN             NaN          NaN                  NaN
#
#   home_phone_number home_email_address bus_city bus_state_code bus_country  \
# 0               NaN                NaN      NaN            NaN         NaN
# 1               NaN                NaN      NaN            NaN         NaN
#
#   bus_phone_area_code bus_phone_number bus_email_address first_name last_name  \
# 0                 NaN              NaN               NaN        NaN       NaN
# 1                 NaN              NaN               NaN        NaN       NaN
#
#   pref_name_sort email_switch saa_email_address gsb_email_address  \
# 0            NaN          NaN               NaN               NaN
# 1            NaN          NaN               NaN               NaN
#
#   other_email_address pref_phone_area_code pref_phone_number  \
# 0                 NaN                  NaN               NaN
# 1                 NaN                  NaN               NaN
#
#   pref_phone_addr_type memb_status_desc short_degree_string  \
# 0                  NaN              NaN                 NaN
# 1                  NaN              NaN                 NaN
#
#   parent_degree_string short_degree_string_spouse parent_degree_string_spouse  \
# 0                  NaN                        NaN                         NaN
# 1                  NaN                        NaN                         NaN
#
#   primary_sort_name plan_name primary_ind
# 0               NaN       NaN         NaN
# 1               NaN       NaN         NaN

# %%
def update_df(df, name1, name2, email):
    df.at[df.set_index('Email Address').loc[email]['First Name']] = name1
    df.at[df.set_index('First Name').loc[name1]['Preferred Email Address']] = email
    df.at[df.set_index('First Name').loc[name1]['Last Name']] = name2
    return df

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Next step would be to take a proactive approach to mitigate the number of emails that bounce in the future. I would suggest using the salesforce dataset to check for recent grads to reach out before they lose their student emails and ask for updated contact information and their subsequent plans after graduation. It would be easier to update records proactively when we still have accurate contact information. For subsequent plans after graduation, this would be to keeping location information of members to more accurately send regional events and functions.
