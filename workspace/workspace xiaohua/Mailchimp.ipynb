# %%
import pandas as pd
import random
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
stanford = pd.read_excel('../data/SAA_FakeDB.xlsx')

# %%
stanford
# Out:
#     pref_mail_name  pref_class_year home_city home_state_code home_country  \
# 0              NaN              NaN    London             NaN          NaN
# 1              NaN              NaN    Madrid             NaN        Japan
# 2              NaN              NaN  Shanghai             NaN          USA
# 3              NaN              NaN   Chicago              IL          UAE
# 4              NaN           1994.0     Seoul             NaN            *
# ..             ...              ...       ...             ...          ...
# 95             NaN              NaN   Beijing             NaN          UAE
# 96             NaN              NaN     Seoul             NaN          UAE
# 97             NaN              NaN   Beijing             NaN          UAE
# 98             NaN           2011.0       NaN             NaN            *
# 99             NaN              NaN  Shanghai             NaN            *
#
# ...

# %%
titles = ['Dr.', 'Mr.', 'Ms.', 'Mrs.']

# %%
stanford.pref_mail_name = random.choice(titles) + " " + stanford.first_name + " " + stanford.last_name

# %%
stanford
# Out:
#             pref_mail_name  pref_class_year home_city home_state_code  \
# 0          Dr. Linda Brown              NaN    London             NaN
# 1       Dr. Mary Rodriguez              NaN    Madrid             NaN
# 2      Dr. Sarah Rodriguez              NaN  Shanghai             NaN
# 3        Dr. Jessica Jones              NaN   Chicago              IL
# 4     Dr. Jessica Martinez           1994.0     Seoul             NaN
# ..                     ...              ...       ...             ...
# 95    Dr. Oliver Rodriguez              NaN   Beijing             NaN
# 96         Dr. James Brown              NaN     Seoul             NaN
# 97  Dr. Elizabeth Martinez              NaN   Beijing             NaN
# 98         Dr. Sarah Brown           2011.0       NaN             NaN
# 99     Dr. Elizabeth Smith              NaN  Shanghai             NaN
#
#    home_country  home_phone_area_code home_phone_number  \
# 0           NaN                   NaN               NaN
# ...

# %%
sample1 = stanford[stanford['first_name'] == 'Jessica']

# %%
sample1
# Out:
#           pref_mail_name  pref_class_year home_city home_state_code  \
# 3      Dr. Jessica Jones              NaN   Chicago              IL
# 4   Dr. Jessica Martinez           1994.0     Seoul             NaN
# 15   Dr. Jessica Johnson              NaN    Boston              MA
# 23  Dr. Jessica Martinez              NaN     Dubai             NaN
# 57     Dr. Jessica Smith           1993.0   Beijing             NaN
# 60     Dr. Jessica Jones              NaN    Madrid             NaN
# 75     Dr. Jessica Jones              NaN   Chicago              IL
# 81     Dr. Jessica Brown              NaN    Boston              MA
# 84    Dr. Jessica Garcia              NaN    Madrid             NaN
#
#      home_country  home_phone_area_code home_phone_number  \
# 3             UAE                   NaN               NaN
# 4               *                   NaN               NaN
# 15          Japan                   NaN                 *
# ...

# %%
sample2 = stanford[stanford['first_name'] == 'Oliver']

# %%
sample2
# Out:
#           pref_mail_name  pref_class_year home_city home_state_code  \
# 37      Dr. Oliver Davis           2008.0       NaN             NaN
# 47      Dr. Oliver Brown           1991.0  Shanghai             NaN
# 62      Dr. Oliver Smith           2006.0     Seoul             NaN
# 78     Dr. Oliver Miller              NaN         *               *
# 87      Dr. Oliver Davis              NaN         *               *
# 95  Dr. Oliver Rodriguez              NaN   Beijing             NaN
#
#      home_country  home_phone_area_code home_phone_number home_email_address  \
# 37          Japan                   NaN               NaN                  *
# 47            USA                   NaN               NaN                NaN
# 62  United States                   NaN                 *                NaN
# 78              *                   NaN                 *                  *
# 87            NaN                   NaN      185 5256-552                  *
# ...

# %% [markdown]
# It has two Ms. Jessica Jones and unques so will insert this into the mailchimp sample

# %%
samples = pd.concat([sample1, sample2], axis = 0)

# %%
samples
# Out:
#           pref_mail_name  pref_class_year home_city home_state_code  \
# 3      Dr. Jessica Jones              NaN   Chicago              IL
# 4   Dr. Jessica Martinez           1994.0     Seoul             NaN
# 15   Dr. Jessica Johnson              NaN    Boston              MA
# 23  Dr. Jessica Martinez              NaN     Dubai             NaN
# 57     Dr. Jessica Smith           1993.0   Beijing             NaN
# 60     Dr. Jessica Jones              NaN    Madrid             NaN
# 75     Dr. Jessica Jones              NaN   Chicago              IL
# 81     Dr. Jessica Brown              NaN    Boston              MA
# 84    Dr. Jessica Garcia              NaN    Madrid             NaN
# 37      Dr. Oliver Davis           2008.0       NaN             NaN
# 47      Dr. Oliver Brown           1991.0  Shanghai             NaN
# 62      Dr. Oliver Smith           2006.0     Seoul             NaN
# 78     Dr. Oliver Miller              NaN         *               *
# ...

# %%
#loading in the mail chimp
mailchimp = pd.read_csv('../data/MailChimp cleaned records headers.csv')

# %%
mailchimp
# Out:
# Empty DataFrame
# Columns: [Email Address, First Name, Last Name, Board Member, Gender, Chapter, Reunion Year, Country, Degree, MEMBER_RATING, OPTIN_TIME, OPTIN_IP, CONFIRM_TIME, CONFIRM_IP, LATITUDE, LONGITUDE, GMTOFF, DSTOFF, TIMEZONE, CC, REGION, CLEAN_TIME, CLEAN_CAMPAIGN_TITLE, CLEAN_CAMPAIGN_ID, LEID, EUID, NOTES, TAGS]
# Index: []

# %%
mailchimp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email Address         0 non-null      object
#  1   First Name            0 non-null      object
#  2   Last Name             0 non-null      object
#  3   Board Member          0 non-null      object
#  4   Gender                0 non-null      object
#  5   Chapter               0 non-null      object
#  6   Reunion Year          0 non-null      object
#  7   Country               0 non-null      object
#  8   Degree                0 non-null      object
#  9   MEMBER_RATING         0 non-null      object
#  10  OPTIN_TIME            0 non-null      object
#  11  OPTIN_IP              0 non-null      object
#  12  CONFIRM_TIME          0 non-null      object
#  13  CONFIRM_IP            0 non-null      object
#  14  LATITUDE              0 non-null      object
# ...

# %%
mailchimp.columns = [x.replace(' ','_').lower() for x in mailchimp.columns]

# %%
mailchimp
# Out:
# Empty DataFrame
# Columns: [email_address, first_name, last_name, board_member, gender, chapter, reunion_year, country, degree, member_rating, optin_time, optin_ip, confirm_time, confirm_ip, latitude, longitude, gmtoff, dstoff, timezone, cc, region, clean_time, clean_campaign_title, clean_campaign_id, leid, euid, notes, tags]
# Index: []

# %%
num_ofDesiredRecords = 20

# %%
first_name = sample1.first_name.to_list()

# %%
mailchimp.first_name = first_name

# %%
mailchimp
# Out:
#   email_address first_name last_name board_member gender chapter reunion_year  \
# 0           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 1           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 2           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 3           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 4           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 5           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 6           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 7           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
# 8           NaN    Jessica       NaN          NaN    NaN     NaN          NaN
#
#   country degree member_rating optin_time optin_ip confirm_time confirm_ip  \
# 0     NaN    NaN           NaN        NaN      NaN          NaN        NaN
# ...

# %%
mailchimp_subset = pd.DataFrame(samples.first_name, columns = mailchimp.columns)

# %%
mailchimp_subset.last_name = samples.last_name

# %%
mailchimp_subset.fillna('*', inplace = True)

# %%
mailchimp_subset.email_address = samples.home_email_address

# %%
mailchimp_subset
# Out:
#                       email_address first_name  last_name board_member gender  \
# 3                               NaN    Jessica      Jones            *      *
# 4                               NaN    Jessica   Martinez            *      *
# 15                                *    Jessica    Johnson            *      *
# 23         j.martinez3964@gmail.com    Jessica   Martinez            *      *
# 57   j.smith8032@stanfordalumni.org    Jessica      Smith            *      *
# 60                                *    Jessica      Jones            *      *
# 75                                *    Jessica      Jones            *      *
# 81  jessicab7734@stanfordalumni.org    Jessica      Brown            *      *
# 84                              NaN    Jessica     Garcia            *      *
# 37                                *     Oliver      Davis            *      *
# 47                              NaN     Oliver      Brown            *      *
# ...

# %%
mailchimp_subset.to_csv('../data/mailchimp.csv', index = False)

# %%
def mailchimp(filepath_csv_file):
    df = pd.read_csv(filepath_csv_file)
    return df

# %%
mailchimp('../data/mailchimp.csv')
# Out:
#                       email_address first_name  last_name board_member gender  \
# 0                               NaN    Jessica      Jones            *      *
# 1                               NaN    Jessica   Martinez            *      *
# 2                                 *    Jessica    Johnson            *      *
# 3          j.martinez3964@gmail.com    Jessica   Martinez            *      *
# 4    j.smith8032@stanfordalumni.org    Jessica      Smith            *      *
# 5                                 *    Jessica      Jones            *      *
# 6                                 *    Jessica      Jones            *      *
# 7   jessicab7734@stanfordalumni.org    Jessica      Brown            *      *
# 8                               NaN    Jessica     Garcia            *      *
# 9                                 *     Oliver      Davis            *      *
# 10                              NaN     Oliver      Brown            *      *
# ...

# %%
def saadb_info():
    pass

# %%
first_name = input('Name:')
surname = input('Surname:')
